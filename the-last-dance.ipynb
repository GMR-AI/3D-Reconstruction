# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import plotly.graph_objects as go
import cv2
import os
import pyntcloud
import pandas as pd
from scipy.optimize import least_squares
from scipy.sparse import lil_matrix

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return images

# %%
def feature_extraction_set(images):
    sift = cv2.SIFT_create()

    kp, des = [], []
    for im in images:
        kp_tmp, des_tmp = sift.detectAndCompute(im, None) # This assumes the extraction method to be from the CV2 library
        kp.append(kp_tmp)
        des.append(des_tmp)
    return kp, des # Can't turn them into a np array since their shape can be inhomogeneous

# %%
def feature_matching_set(kp, des):
    # Initialize FLANN matching
    FLANN_INDEX_KDTREE = 0
    index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
    search_params = dict(checks=50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)

    matches = {} # Dict for easier access to each match
    for i in range(len(kp)):
        for j in range(i+1, len(kp)): # Only match each image with the rest, we don't need the full matrix
            matches_tmp = flann.knnMatch(des[i], des[j], k=2)

            # Lowe's ratio test
            good_matches = [m for m, n in matches_tmp if m.distance < 0.7 * n.distance]

            if len(good_matches) >= 4:
                # RANSAC to find homography and get inlier's mask
                pts1 = np.float32([kp[i][m.queryIdx].pt for m in good_matches]).reshape(-1, 1, 2)
                pts2 = np.float32([kp[j][m.trainIdx].pt for m in good_matches]).reshape(-1, 1, 2)
                _, mask = cv2.findHomography(pts1, pts2, cv2.RANSAC, 5.0)

                inliers = [good_matches[k] for k in range(len(good_matches)) if mask[k]==1]
                matches[(i,j)] = inliers
            else:
                matches[(i,j)] = []
    
    return matches

# %%
def find_matches(matcher, keypoints, descriptors, lowes_ratio=0.7):
    matches = []
    n_imgs = len(keypoints)
    for i in range(n_imgs):
        matches.append([])
        for j in range(n_imgs):
            if j <= i: matches[i].append(None)
            else:
                match = []
                m = matcher.knnMatch(descriptors[i], descriptors[j], k=2)
                for k in range(len(m)):
                    try:
                        if m[k][0].distance < lowes_ratio*m[k][1].distance:
                            match.append(m[k][0])
                    except:
                        continue
                matches[i].append(match)
    return matches


def remove_outliers(matches, keypoints):
    for i in range(len(matches)):
        for j in range(len(matches[i])):
            if j <= i: continue
            if len(matches[i][j]) < 20:
                matches[i][j] = []
                continue
            kpts_i = []
            kpts_j = []
            for k in range(len(matches[i][j])):
                kpts_i.append(keypoints[i][matches[i][j][k].queryIdx].pt)
                kpts_j.append(keypoints[j][matches[i][j][k].trainIdx].pt)
            kpts_i = np.int32(kpts_i)
            kpts_j = np.int32(kpts_j)
            F, mask = cv2.findFundamentalMat(kpts_i, kpts_j, cv2.FM_RANSAC, ransacReprojThreshold=3)
            if np.linalg.det(F) > 1e-7: raise ValueError(f"Bad F_mat between images: {i}, {j}. Determinant: {np.linalg.det(F)}")
            matches[i][j] = np.array(matches[i][j])
            if mask is None:
                matches[i][j] = []
                continue
            matches[i][j] = matches[i][j][mask.ravel() == 1]
            matches[i][j] = list(matches[i][j])

            if len(matches[i][j]) < 20:
                matches[i][j] = []
                continue

    return matches

# %%
def create_img_adjacency_matrix(n_imgs, matches):
    num_img_pairs = 0
    num_pairs = 0
    pairs = []
    img_adjacency = np.zeros((n_imgs, n_imgs))
    for i in range(len(matches)):
        for j in range(len(matches[i])):
            if j <= i: continue
            num_pairs += 1
            if len(matches[i][j]) > 0:
                num_img_pairs += 1
                pairs.append((i,j))
                img_adjacency[i][j] = 1

    list_of_img_pairs = pairs
    return img_adjacency, list_of_img_pairs

# %%
import numpy as np
import random
import cv2

class Point3D_with_views:
    def __init__(self, point3d, source_2dpt_idxs):
        self.point3d = point3d
        self.source_2dpt_idxs = source_2dpt_idxs

def best_img_pair(img_adjacency, matches, keypoints, K, top_x_perc=0.2):
    num_matches = []

    for i in range(img_adjacency.shape[0]):
        for j in range(img_adjacency.shape[1]):
            if img_adjacency[i][j] == 1:
                num_matches.append(len(matches[i][j]))

    num_matches = sorted(num_matches, reverse=True)
    min_match_idx = int(len(num_matches)*top_x_perc)
    min_matches = num_matches[min_match_idx]
    best_R = 0
    best_pair = None

    #For all img pairs in top xth %ile of matches, find pair with greatest rotation between images.
    for i in range(img_adjacency.shape[0]):
        for j in range(img_adjacency.shape[1]):
            if img_adjacency[i][j] == 1:
                if len(matches[i][j]) > min_matches:
                    kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs = get_aligned_kpts(i, j, keypoints, matches)
                    E, _ = cv2.findEssentialMat(kpts_i, kpts_j, K, cv2.FM_RANSAC, 0.999, 1.0)
                    points, R1, t1, mask = cv2.recoverPose(E, kpts_i, kpts_j, K)
                    rvec, _ = cv2.Rodrigues(R1)
                    rot_angle = abs(rvec[0]) +abs(rvec[1]) + abs(rvec[2])# sum rotation angles for each dimension
                    if (rot_angle > best_R or best_pair == None) and points == len(kpts_i): #Ensure recoverPose worked.
                        best_R = rot_angle
                        best_pair = (i,j)

    return best_pair

def get_aligned_kpts(i, j, keypoints, matches, mask=None):
    if mask is None:
        mask = np.ones(len(matches[i][j])) #if no mask is given, all matches used. This is helpful if we only want to triangulate certain matches.

    kpts_i, kpts_i_idxs, kpts_j, kpts_j_idxs = [], [], [], []
    for k in range(len(matches[i][j])):
        if mask[k] == 0: continue
        kpts_i.append(keypoints[i][matches[i][j][k].queryIdx].pt)
        kpts_i_idxs.append(matches[i][j][k].queryIdx)
        kpts_j.append(keypoints[j][matches[i][j][k].trainIdx].pt)
        kpts_j_idxs.append(matches[i][j][k].trainIdx)
    kpts_i = np.array(kpts_i)
    kpts_j = np.array(kpts_j)
    kpts_i = np.expand_dims(kpts_i, axis=1) #this seems to be required for cv2.undistortPoints and cv2.trangulatePoints to work
    kpts_j = np.expand_dims(kpts_j, axis=1)

    return kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs

def triangulate_points_and_reproject(R_l, t_l, R_r, t_r, K, points3d_with_views, img_idx1, img_idx2, kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs, reproject=True):
    print(f"Triangulating: {len(kpts_i)} points.")
    P_l = np.dot(K, np.hstack((R_l, t_l)))
    P_r = np.dot(K, np.hstack((R_r, t_r)))

    kpts_i = np.squeeze(kpts_i)
    kpts_i = kpts_i.transpose()
    kpts_i = kpts_i.reshape(2,-1)
    kpts_j = np.squeeze(kpts_j)
    kpts_j = kpts_j.transpose()
    kpts_j = kpts_j.reshape(2,-1)

    point_4d_hom = cv2.triangulatePoints(P_l, P_r, kpts_i, kpts_j)
    points_3D = cv2.convertPointsFromHomogeneous(point_4d_hom.transpose())
    for i in range(kpts_i.shape[1]):
        source_2dpt_idxs = {img_idx1:kpts_i_idxs[i], img_idx2:kpts_j_idxs[i]}
        pt = Point3D_with_views(points_3D[i], source_2dpt_idxs)
        points3d_with_views.append(pt)

    if reproject:
        kpts_i = kpts_i.transpose()
        kpts_j = kpts_j.transpose()
        rvec_l, _ = cv2.Rodrigues(R_l)
        rvec_r, _ = cv2.Rodrigues(R_r)
        projPoints_l, _ = cv2.projectPoints(points_3D, rvec_l, t_l, K, distCoeffs=np.array([]))
        projPoints_r, _ = cv2.projectPoints(points_3D, rvec_r, t_r, K, distCoeffs=np.array([]))
        delta_l , delta_r = [], []
        for i in range(len(projPoints_l)):
            delta_l.append(abs(projPoints_l[i][0][0] - kpts_i[i][0]))
            delta_l.append(abs(projPoints_l[i][0][1] - kpts_i[i][1]))
            delta_r.append(abs(projPoints_r[i][0][0] - kpts_j[i][0]))
            delta_r.append(abs(projPoints_r[i][0][1] - kpts_j[i][1]))
        avg_error_l = sum(delta_l)/len(delta_l)
        avg_error_r = sum(delta_r)/len(delta_r)
        print(f"Average reprojection error for just-triangulated points on image {img_idx1} is:", avg_error_l, "pixels.")
        print(f"Average reprojection error for just-triangulated points on image {img_idx2} is:", avg_error_r, "pixels.")
        errors = list(zip(delta_l, delta_r))
        return points3d_with_views, errors, avg_error_l, avg_error_r

    return points3d_with_views

def initialize_reconstruction(keypoints, matches, K, img_idx1, img_idx2):
    kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs = get_aligned_kpts(img_idx1, img_idx2, keypoints, matches)
    E, _ = cv2.findEssentialMat(kpts_i, kpts_j, K, cv2.FM_RANSAC, 0.999, 1.0)
    points, R1, t1, mask = cv2.recoverPose(E, kpts_i, kpts_j, K)
    assert abs(np.linalg.det(R1)) - 1 < 1e-7

    R0 = np.eye(3, 3)
    t0 = np.zeros((3, 1))

    points3d_with_views = []
    points3d_with_views = triangulate_points_and_reproject(
        R0, t0, R1, t1, K, points3d_with_views, img_idx1, img_idx2, kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs, reproject=False)

    return R0, t0, R1, t1, points3d_with_views

def get_idxs_in_correct_order(idx1, idx2):
    if idx1 < idx2: return idx1, idx2
    else: return idx2, idx1

def images_adjacent(i, j, img_adjacency):
    if img_adjacency[i][j] == 1 or img_adjacency[j][i] == 1:
        return True
    else:
        return False

def has_resected_pair(unresected_idx, resected_imgs, img_adjacency):
    for idx in resected_imgs:
        if img_adjacency[unresected_idx][idx] == 1 or img_adjacency[idx][unresected_idx] == 1:
            return True
    return False

def has_unresected_pair(resected_idx, unresected_imgs, img_adjacency):
    for idx in unresected_imgs:
        if img_adjacency[resected_idx][idx] == 1 or img_adjacency[idx][resected_idx] == 1:
            return True
    return False


def next_img_pair_to_grow_reconstruction(n_imgs, init_pair, resected_imgs, unresected_imgs, img_adjacency):
    if len(unresected_imgs) == 0: raise ValueError('Should not check next image to resect if all have been resected already!')
    straddle = False
    if init_pair[1] - init_pair[0] > n_imgs/2 : straddle = True #initial pair straddles "end" of the circle (ie if init pair is idxs (0, 49) for 50 images)

    init_arc = init_pair[1] - init_pair[0] + 1 # Number of images between and including initial pair

    #fill in images between initial pair
    if len(resected_imgs) < init_arc:
        if straddle == False: idx = resected_imgs[-2] + 1
        else: idx = resected_imgs[-1] + 1
        while True:
            if idx not in resected_imgs:
                prepend = True
                unresected_idx = idx
                resected_idx = random.choice(resected_imgs)
                return resected_idx, unresected_idx, prepend
            idx = idx + 1 % n_imgs

    extensions = len(resected_imgs) - init_arc # How many images have been resected after the initial arc
    if straddle == True: #smaller init_idx should be increased and larger decreased
        if extensions % 2 == 0:
            unresected_idx = (init_pair[0] + int(extensions/2) + 1) % n_imgs
            resected_idx = (unresected_idx - 1) % n_imgs
        else:
            unresected_idx = (init_pair[1] - int(extensions/2) - 1) % n_imgs
            resected_idx = (unresected_idx + 1) % n_imgs
    else:
        if extensions % 2 == 0:
            unresected_idx = (init_pair[1] + int(extensions/2) + 1) % n_imgs
            resected_idx = (unresected_idx - 1) % n_imgs
        else:
            unresected_idx = (init_pair[0] - int(extensions/2) - 1) % n_imgs
            resected_idx = (unresected_idx + 1) % n_imgs

    prepend = False
    return resected_idx, unresected_idx, prepend

def check_and_get_unresected_point(resected_kpt_idx, match, resected_idx, unresected_idx):
    if resected_idx < unresected_idx:
        if resected_kpt_idx == match.queryIdx:
            unresected_kpt_idx = match.trainIdx
            success = True
            return unresected_kpt_idx, success
        else:
            return None, False
    elif unresected_idx < resected_idx:
        if resected_kpt_idx == match.trainIdx:
            unresected_kpt_idx = match.queryIdx
            success = True
            return unresected_kpt_idx, success
        else:
            return None, False

def get_correspondences_for_pnp(resected_idx, unresected_idx, pts3d, matches, keypoints):
    idx1, idx2 = get_idxs_in_correct_order(resected_idx, unresected_idx)
    triangulation_status = np.ones(len(matches[idx1][idx2])) # if triangulation_status[x] = 1, then matches[x] used for triangulation
    pts3d_for_pnp = []
    pts2d_for_pnp = []
    for pt3d in pts3d:
        if resected_idx not in pt3d.source_2dpt_idxs: continue
        resected_kpt_idx = pt3d.source_2dpt_idxs[resected_idx]
        for k in range(len(matches[idx1][idx2])):
            unresected_kpt_idx, success = check_and_get_unresected_point(resected_kpt_idx, matches[idx1][idx2][k], resected_idx, unresected_idx)
            if not success: continue
            pt3d.source_2dpt_idxs[unresected_idx] = unresected_kpt_idx #Add new 2d/3d correspondences to 3D point object
            pts3d_for_pnp.append(pt3d.point3d)
            pts2d_for_pnp.append(keypoints[unresected_idx][unresected_kpt_idx].pt)
            triangulation_status[k] = 0

    return pts3d, pts3d_for_pnp, pts2d_for_pnp, triangulation_status

def do_pnp(pts3d_for_pnp, pts2d_for_pnp, K, iterations=200, reprojThresh=5):
    list_pts3d_for_pnp = pts3d_for_pnp
    list_pts2d_for_pnp = pts2d_for_pnp
    pts3d_for_pnp = np.squeeze(np.array(pts3d_for_pnp))
    pts2d_for_pnp = np.expand_dims(np.squeeze(np.array(pts2d_for_pnp)), axis=1)
    num_pts = len(pts3d_for_pnp)

    highest_inliers = 0
    for i in range(iterations):
        pt_idxs = np.random.choice(num_pts, 6, replace=False)
        pts3 = np.array([pts3d_for_pnp[pt_idxs[i]] for i in range(len(pt_idxs))])
        pts2 = np.array([pts2d_for_pnp[pt_idxs[i]] for i in range(len(pt_idxs))])
        _, rvec, tvec = cv2.solvePnP(pts3, pts2, K, distCoeffs=np.array([]), flags=cv2.SOLVEPNP_ITERATIVE)
        R, _ = cv2.Rodrigues(rvec)
        pnp_errors, projpts, avg_err, perc_inliers = test_reproj_pnp_points(list_pts3d_for_pnp, list_pts2d_for_pnp, R, tvec, K, rep_thresh=reprojThresh)
        if highest_inliers < perc_inliers:
            highest_inliers = perc_inliers
            best_R = R
            best_tvec = tvec
    R = best_R
    tvec = best_tvec
    print('rvec:', rvec,'\n\ntvec:', tvec)

    return R, tvec

def prep_for_reproj(img_idx, points3d_with_views, keypoints):
    points_3d = []
    points_2d = []
    pt3d_idxs = []
    i = 0
    for pt3d in points3d_with_views:
        if img_idx in pt3d.source_2dpt_idxs.keys():
            pt3d_idxs.append(i)
            points_3d.append(pt3d.point3d)
            kpt_idx = pt3d.source_2dpt_idxs[img_idx]
            points_2d.append(keypoints[img_idx][kpt_idx].pt)
        i += 1

    return np.array(points_3d), np.array(points_2d), pt3d_idxs

def calculate_reproj_errors(projPoints, points_2d):
    assert len(projPoints) == len(points_2d)
    delta = []
    for i in range(len(projPoints)):
        delta.append(abs(projPoints[i] - points_2d[i]))

    average_delta = sum(delta)/len(delta) # 2-vector, average error for x and y coord
    average_delta = (average_delta[0] + average_delta[1])/2 # average error overall

    return average_delta, delta

def get_reproj_errors(img_idx, points3d_with_views, R, t, K, keypoints, distCoeffs=np.array([])):
    points_3d, points_2d, pt3d_idxs = prep_for_reproj(img_idx, points3d_with_views, keypoints)
    rvec, _ = cv2.Rodrigues(R)
    projPoints, _ = cv2.projectPoints(points_3d, rvec, t, K, distCoeffs=distCoeffs)
    projPoints = np.squeeze(projPoints)
    avg_error, errors = calculate_reproj_errors(projPoints, points_2d)

    return points_3d, points_2d, avg_error, errors

def test_reproj_pnp_points(pts3d_for_pnp, pts2d_for_pnp, R_new, t_new, K, rep_thresh=5):
    errors = []
    projpts = []
    inliers = []
    for i in range(len(pts3d_for_pnp)):
        Xw = pts3d_for_pnp[i][0]
        Xr = np.dot(R_new, Xw).reshape(3,1)
        Xc = Xr + t_new
        x = np.dot(K, Xc)
        x /= x[2]
        errors.append([np.float64(x[0] - pts2d_for_pnp[i][0]), np.float64(x[1] - pts2d_for_pnp[i][1])])
        projpts.append(x)
        if abs(errors[-1][0]) > rep_thresh or abs(errors[-1][1]) > rep_thresh: inliers.append(0)
        else: inliers.append(1)
    a = 0
    for e in errors:
        a = a + abs(e[0]) + abs(e[1])
    avg_err = a/(2*len(errors))
    perc_inliers = sum(inliers)/len(inliers)

    return errors, projpts, avg_err, perc_inliers

# %%
def bundle_adjustment_sparsity(n_cameras, n_points, camera_indices, point_indices):
    """

    :param n_cameras Integer. Number of cameras/images currently resected
    :param n_points: number of distinct 3D points that have been triangulated
    :param camera_indices: List. Value at ith position is index of camera that sees ith 2D point
    :param point_indices: List. Value at ith position is index of 3D point that sees ith 2D point
    """
    m = camera_indices.size * 2
    n = n_cameras * 12 + n_points * 3
    A = lil_matrix((m, n), dtype=int)

    i = np.arange(camera_indices.size)
    for s in range(12):
        A[2 * i, camera_indices * 12 + s] = 1
        A[2 * i + 1, camera_indices * 12 + s] = 1

    for s in range(3):
        A[2 * i, n_cameras * 12 + point_indices * 3 + s] = 1
        A[2 * i + 1, n_cameras * 12 + point_indices * 3 + s] = 1

    return A

def project(points, camera_params, K):
    """
    Projects 3D points onto camera coordinates

    :param points: N x 3 List of 3D point coordinates
    :param camera_params: N x 12 List of 12D camera parameters (r1, ... r9, t1, t2, t3)
    :param K: Intrinsics matrix
    """
    points_proj = []

    for idx in range(len(camera_params)): # idx applies to both points and cam_params, they are = length vectors
        R = camera_params[idx][:9].reshape(3,3)
        rvec, _ = cv2.Rodrigues(R)
        t = camera_params[idx][9:]
        pt = points[idx]
        pt = np.expand_dims(pt, axis=0)
        pt, _ = cv2.projectPoints(pt, rvec, t, K, distCoeffs=np.array([]))
        pt = np.squeeze(np.array(pt))
        points_proj.append(pt)

    return points_proj

def fun(params, n_cameras, n_points, camera_indices, point_indices, points_2d, K):
    """Compute residuals (ie reprojection error) for Bundle Adjustment.

    :param params: List of all parameters. First n_cameras*12 parameters are (r1, ..., r9, t1, t2, t3)
    for each resected camera. Remaining n_points*3 paramaters are (x, y, z) coord of each triangulated point
    :param n_cameras: Integer. # of resected cameras
    :param n_points: Integer. # of triangulated points
    :param camera_indices: List of indices of cameras viewing each 2D observation
    :param point_indices: List of indices of 3D points corresponding to each 2D observation
    :points_2d: 2D pixel coordinates of each observation by a camera of a 3D point
    :param K: Intrinsics matrix
    """
    camera_params = params[:n_cameras * 12].reshape((n_cameras, 12))
    points_3d = params[n_cameras * 12:].reshape((n_points, 3))
    points_proj = project(points_3d[point_indices], camera_params[camera_indices], K)
    return (points_proj - points_2d).ravel()

def do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, keypoints, K, ftol):
    """
    Perform Bundle Adjustment on all currently resected images and all triangulated 3D points. Return updated
    values for camera poses and 3D point coordinates.

    :param points3d_with_views: List of Point3D_with_views objects.
    :param R_mats: Dict mapping index of resected cameras to their Rotation matrix
    :param t_vecs: Dict mapping index of resected cameras to their translation vector
    :param resected_imgs: List of indices of resected images
    :param keypoints: List of lists of cv2.Keypoint objects. keypoints[i] is list for image i.
    :param ftol: Tolerance for change in total reprojection error. Used so scipy.optimize.least_squares knows
    when to stop adjusting
    """
    point_indices = []
    points_2d = []
    camera_indices = []
    points_3d = []
    camera_params = []
    BA_cam_idxs = {} # maps from true cam indices to 'normalized' (i.e 11, 23, 31 maps to -> 0, 1, 2)
    cam_count = 0

    for r in resected_imgs:
        BA_cam_idxs[r] = cam_count
        camera_params.append(np.hstack((R_mats[r].ravel(), t_vecs[r].ravel())))
        cam_count += 1

    for pt3d_idx in range(len(points3d_with_views)):
        points_3d.append(points3d_with_views[pt3d_idx].point3d)
        for cam_idx, kpt_idx in points3d_with_views[pt3d_idx].source_2dpt_idxs.items():
            if cam_idx not in resected_imgs: continue
            point_indices.append(pt3d_idx)
            camera_indices.append(BA_cam_idxs[cam_idx])#append normalized cam idx
            points_2d.append(keypoints[cam_idx][kpt_idx].pt)
    if len(points_3d[0]) == 3: points_3d = np.expand_dims(points_3d, axis=0)

    point_indices = np.array(point_indices)
    points_2d = np.array(points_2d)
    camera_indices = np.array(camera_indices)
    points_3d = np.squeeze(points_3d)
    camera_params = np.array(camera_params)

    n_cameras = camera_params.shape[0]
    n_points = points_3d.shape[0]
    x0 = np.hstack((camera_params.ravel(), points_3d.ravel()))
    A = bundle_adjustment_sparsity(n_cameras, n_points, camera_indices, point_indices)

    res = least_squares(fun, x0, jac_sparsity=A, verbose=2, x_scale='jac', loss='linear', ftol=ftol, xtol=1e-12, method='trf',
                        args=(n_cameras, n_points, camera_indices, point_indices, points_2d, K))

    adjusted_camera_params = res.x[:n_cameras * 12].reshape(n_cameras, 12)
    adjusted_points_3d = res.x[n_cameras * 12:].reshape(n_points, 3)
    adjusted_R_mats = {}
    adjusted_t_vecs = {}
    for true_idx, norm_idx in BA_cam_idxs.items():
        adjusted_R_mats[true_idx] = adjusted_camera_params[norm_idx][:9].reshape(3,3)
        adjusted_t_vecs[true_idx] = adjusted_camera_params[norm_idx][9:].reshape(3,1)
    R_mats = adjusted_R_mats
    t_vecs = adjusted_t_vecs
    for pt3d_idx in range(len(points3d_with_views)):
        points3d_with_views[pt3d_idx].point3d = np.expand_dims(adjusted_points_3d[pt3d_idx], axis=0)

    return points3d_with_views, R_mats, t_vecs

# %%
def normalize(pts):
    x_mean = np.mean(pts[:, 0])
    y_mean = np.mean(pts[:, 1])
    sigma = np.mean(np.sqrt((pts[:, 0] - x_mean) ** 2 + (pts[:, 1] - y_mean) ** 2))
    M = np.sqrt(2) / sigma
    T = np.array([
        [M, 0, -M * x_mean],
        [0, M, -M * y_mean],
        [0, 0, 1]
    ])
    return T

def eight_point_algorithm(pts1, pts2):

    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1]))).T
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1]))).T

    # Normalization
    T = normalize(pts1_homo)
    T_prime = normalize(pts2_homo)


    pts1_homo = (T @ pts1_homo.T).T
    pts2_homo = (T_prime @ pts2_homo.T).T

    # x2.T*F*x1=0
    # A*f=0, f is F flattened into a 1D array
    

    # Create A
    A = np.zeros((pts1.shape[1], 9))
    for i in range(pts1.shape[1]):
        A[i] = np.array([
            pts1_homo[i,0]*pts2_homo[i,0], pts1_homo[i,1]*pts2_homo[i,0], pts1_homo[i,2]*pts2_homo[i,0],
            pts1_homo[i,0]*pts2_homo[i,1], pts1_homo[i,1]*pts2_homo[i,1], pts1_homo[i,2]*pts2_homo[i,1],
            pts1_homo[i,0]*pts2_homo[i,2], pts1_homo[i,1]*pts2_homo[i,2], pts1_homo[i,2]*pts2_homo[i,2]
            ])
    
    # Solve Af=0 using svd
    U,S,Vt = np.linalg.svd(A)
    F = Vt[-1,:].reshape((3,3))

    # Enforce rank2 constraint
    U,S,Vt = np.linalg.svd(F)
    S[-1] = 0
    F = U @ np.diag(S) @ Vt

    F = T_prime.T @ F @ T
    return F

# %%
def essential_from_fundamental(K1, F, K2):
    return K1.T @ F @ K2

# %%
def pose_from_essential(E):
    U,_,Vt = np.linalg.svd(E)
    W = np.array([[0, -1, 0], [1, 0, 0], [0, 0, 1]])
    
    Rs = [U @ W @ Vt, U @ W.T @ Vt]
    for i in range(len(Rs)):
        if np.linalg.det(Rs[i]) < 0:
            Rs[i] = Rs[i] * -1

    # Array with all possible camera poses (extrinsics)
    RTs = np.array([
        np.hstack((Rs[0], U[:, 2, np.newaxis])),
        np.hstack((Rs[0], -U[:, 2, np.newaxis])),
        np.hstack((Rs[1], U[:, 2, np.newaxis])),
        np.hstack((Rs[1], -U[:, 2, np.newaxis])),
    ])

    return RTs

# %%
def linear_triangulation(K1, RT1, K2, RT2, pts1, pts2):
    # First, set all points to homogeneous
    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1])))
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1])))

    # Calculate every projection matrix
    P1 = K1 @ RT1
    P2 = K2 @ RT2

    # Solve using svd
    pts3d = np.zeros((3, pts1.shape[1]))
    for i in range(pts1.shape[1]):
        A = np.array([pts1_homo[1,i]*P1[2,:] - P1[1,:],
            P1[0,:] - pts1_homo[0,i]*P1[2,:],
            pts2_homo[1,i]*P2[2,:] - P2[1,:],
            P2[0,:] - pts2_homo[0,i]*P2[2,:]])
        ATA = A.T @ A
        _, _, Vt = np.linalg.svd(ATA)
        pts3d[:, i] = Vt[-1, :3]/Vt[-1, -1]
    
    return pts3d

def linear_triangulation2(P1, P2, pts1, pts2):
    # First, set all points to homogeneous
    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1])))
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1])))

    # Solve using svd
    pts3d = np.zeros((3, pts1.shape[1]))
    for i in range(pts1.shape[1]):
        A = np.array([pts1_homo[1,i]*P1[2,:] - P1[1,:],
                      P1[0,:] - pts1_homo[0,i]*P1[2,:],
                      pts2_homo[1,i]*P2[2,:] - P2[1,:],
                      P2[0,:] - pts2_homo[0,i]*P2[2,:]])
        ATA = A.T @ A
        _, _, Vt = np.linalg.svd(ATA)
        pts3d[:, i] = Vt[-1, :3]/Vt[-1, -1]
    
    return pts3d

# %%
def reprojection(P1, P2, pts3d):
    pts3d_homo = np.vstack((pts3d, np.ones(pts3d.shape[1])))
    pts2d1_homo = np.dot(P1, pts3d_homo)
    pts2d2_homo = np.dot(P2, pts3d_homo)
    return pts2d1_homo/pts2d1_homo[-1], pts2d2_homo/pts2d2_homo[-1]

def double_disambiguation(K1, RT1, K2, RT2s, pts1, pts2, pts3d):
    max_positive_z = 0
    min_error = np.finfo('float').max
    best_RT = None
    best_pts3d = None
    P1 = K1 @ RT1

    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1])))
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1])))

    for i in range(RT2s.shape[0]):
        P2 = K2 @ RT2s[i]
        num_positive_z = np.sum(pts3d[i][2, :] > 0)
        re1_pts2, re2_pts2 = reprojection(P1, P2, pts3d[i])

        err1 = np.sum(np.square(re1_pts2 - pts1_homo))
        err2 = np.sum(np.square(re2_pts2 - pts2_homo))

        err = err1 + err2

        if num_positive_z >= max_positive_z and err < min_error:
            max_positive_z = num_positive_z
            min_error = err
            best_RT = RT2s[i]
            best_pts3d = pts3d[i]
    
    return best_RT, best_pts3d

# %%
def calculate_projection_matrix(K, pts3d, pts2d):
    _, rod, T, _ = cv2.solvePnPRansac(pts3d.T, pts2d.T, K, None)#, flags=cv2.SOLVEPNP_P3P)
    R = cv2.Rodrigues(rod)[0]
    if np.linalg.det(R) < 0:
        R = R * -1
    P = K @ np.hstack((R, T))
    return P

# %%
def plot_model(pts_cloud):
    # Assuming points_3D is your array of 3D points
    x = pts_cloud[0]
    y = pts_cloud[1]
    z = pts_cloud[2]

    fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z,
                                    mode='markers',
                                    marker=dict(size=2, color=z, colorscale='Viridis'))])

    fig.update_layout(scene=dict(xaxis_title='X',
                                yaxis_title='Y',
                                zaxis_title='Z'))

    fig.show()

# %%
def two_images_sfm(im1, im2, K):
    # Feature extraction
    kp, des = feature_extraction_set([im1, im2])

    # Feature matching
    matches = feature_matching_set(kp, des)

    # Fundamental matrix
    pts1 = np.transpose([kp[0][m.queryIdx].pt for m in matches[(0,1)]])
    pts2 = np.transpose([kp[1][m.trainIdx].pt for m in matches[(0,1)]])

    F = eight_point_algorithm(pts1, pts2)

    # Essential matrix
    E = essential_from_fundamental(K, F, K) # In this case, the same intrinsic values apply to all images

    # Get camera extrinsics from Essential matrix
    RT2s = pose_from_essential(E)

    # Define RT for camera 1 (center at world origin and matching orientation)
    RT1 = np.hstack((np.eye(3), np.zeros((3, 1))))
    
    RT2 = RT2s[0]

    pts3d = np.array([linear_triangulation(K, RT1, K, RT2, pts1, pts2) for RT2 in RT2s])

    RT2, pts_cloud = double_disambiguation(K, RT1, K, RT2s, pts1, pts2, pts3d)

    plot_model(pts_cloud)

    # Initialize general Projection matrix list, RTs list and 3d points list

    return K @ RT1, K @ RT2, pts_cloud

# %%
# Load all images
images = np.array(load_images_from_folder('dinos'))

# %%
# K = np.loadtxt('intrinsic_matrix.txt', dtype=float)

height, width = images.shape[1:3]
K = np.array([  # for dino
    [2360, 0, width / 2],
    [0, 2360, height / 2],
    [0, 0, 1]])

# %%
kp, des = feature_extraction_set(images)
matches = feature_matching_set(kp, des)

# %%
image_count = 0
pts_cloud = []
P_list = []

while image_count < images.shape[0]:
    P1, P2, pts3d = two_images_sfm(images[image_count], images[image_count+1], K)
    pts_cloud.append(pts3d)
    image_count += 2
    P_list.append([P1, P2])

    for i in range(image_count, images.shape[0]):
        idx1, idx2, idx3 = i-2, i-1, i
        image_count += 1
        
        # Get Common matches of 3 images
        common_matches1 = [m1 for m1 in matches[(idx1, idx3)] for m2 in matches[(idx2, idx3)] if m1.trainIdx == m2.trainIdx]
        common_matches2 = [m2 for m1 in matches[(idx1, idx3)] for m2 in matches[(idx2, idx3)] if m1.trainIdx == m2.trainIdx]
        
        if len(common_matches1) < 4:
            print('STOP')
            break

        # Triangulate common points
        common_pts1 = np.transpose([kp[idx1][m.queryIdx].pt for m in common_matches1])
        common_pts2 = np.transpose([kp[idx2][m.queryIdx].pt for m in common_matches2])
        common_pts3 = np.transpose([kp[idx3][m.trainIdx].pt for m in common_matches1])

        common_pts3d = linear_triangulation2(P_list[-1][-2], P_list[-1][-1], common_pts1, common_pts2)

        # Get Projection matrix
        P = calculate_projection_matrix(K, common_pts3d, common_pts3)

        P_list[-1].append(P)
        
        # Triangulate
        pts1_list = [np.transpose([kp[j][m.queryIdx].pt for m in matches[(j,idx3)]]) for j in range(idx1, idx3)]
        pts2_list = [np.transpose([kp[idx3][m.trainIdx].pt for m in matches[(j,idx3)]]) for j in range(idx1, idx3)]

        for j in range(2):
            pts3d = linear_triangulation2(P_list[-1][-3+j], P_list[-1][-1], pts1_list[j], pts2_list[j])
            pts_cloud[-1] = np.hstack((pts_cloud[-1], pts3d))
# Out:
# STOP

# %%
for pts in pts_cloud:
    plot_model(pts)

# %%
# Load all images
images = np.array(load_images_from_folder('dinos'))[:-1]
height, width = images.shape[1:3]
K = np.array([  # for dino
    [2360, 0, width / 2],
    [0, 2360, height / 2],
    [0, 0, 1]])

kp, des = feature_extraction_set(images)
matcher = cv2.BFMatcher(cv2.NORM_L1)
matches = find_matches(matcher, kp, des)
matches = remove_outliers(matches, kp)
img_adjacency, list_of_img_pairs = create_img_adjacency_matrix(len(images), matches)

# %%
best_pair = best_img_pair(img_adjacency, matches, kp, K, top_x_perc=0.2)
R0, t0, R1, t1, points3d_with_views = initialize_reconstruction(kp, matches, K, best_pair[0], best_pair[1])

R_mats = {best_pair[0]: R0, best_pair[1]: R1}
t_vecs = {best_pair[0]: t0, best_pair[1]: t1}

resected_imgs = [best_pair[0], best_pair[1]] 
unresected_imgs = [i for i in range(len(images)) if i not in resected_imgs] 
avg_err = 0
# Out:
# Triangulating: 349 points.

# %%
### This cell grows and refines the reconstruction 
BA_chkpts = [3,4,5,6] + [int(6*(1.34**i)) for i in range(25)]
while len(unresected_imgs) > 0:
    resected_idx, unresected_idx, prepend = next_img_pair_to_grow_reconstruction(len(images), best_pair, resected_imgs, unresected_imgs, img_adjacency)
    points3d_with_views, pts3d_for_pnp, pts2d_for_pnp, triangulation_status = get_correspondences_for_pnp(resected_idx, unresected_idx, points3d_with_views, matches, kp)
    if len(pts3d_for_pnp) < 12:
        print(f"{len(pts3d_for_pnp)} is too few correspondences for pnp. Skipping imgs resected:{resected_idx} and unresected:{unresected_idx}")
        print(f"Currently resected imgs: {resected_imgs}, unresected: {unresected_imgs}")
        continue

    R_res = R_mats[resected_idx]
    t_res = t_vecs[resected_idx]
    print(f"Unresected image: {unresected_idx}, resected: {resected_idx}")
    R_new, t_new = do_pnp(pts3d_for_pnp, pts2d_for_pnp, K)
    R_mats[unresected_idx] = R_new
    t_vecs[unresected_idx] = t_new
    if prepend == True: resected_imgs.insert(0, unresected_idx)
    else: resected_imgs.append(unresected_idx)
    unresected_imgs.remove(unresected_idx)
    pnp_errors, projpts, avg_err, perc_inliers = test_reproj_pnp_points(pts3d_for_pnp, pts2d_for_pnp, R_new, t_new, K)
    print(f"Average error of reprojecting points used to resect image {unresected_idx} back onto it is: {avg_err}")
    print(f"Fraction of Pnp inliers: {perc_inliers} num pts used in Pnp: {len(pnp_errors)}")
    
    if resected_idx < unresected_idx:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = get_aligned_kpts(resected_idx, unresected_idx, kp, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = triangulate_points_and_reproject(R_res, t_res, R_new, t_new, K, points3d_with_views, resected_idx, unresected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    else:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = get_aligned_kpts(unresected_idx, resected_idx, kp, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = triangulate_points_and_reproject(R_new, t_new, R_res, t_res, K, points3d_with_views, unresected_idx, resected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    if 0.8 < perc_inliers < 0.95 or 5 < avg_tri_err_l < 10 or 5 < avg_tri_err_r < 10: 
        #If % of inlers from Pnp is too low or triangulation error on either image is too high, bundle adjust
        points3d_with_views, R_mats, t_vecs = do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, kp, K, ftol=1e0)
        
    if len(resected_imgs) in BA_chkpts or len(unresected_imgs) == 0 or perc_inliers <= 0.8 or avg_tri_err_l >= 10 or avg_tri_err_r >= 10:
        #If % of inlers from Pnp is very low or triangulation error on either image is very high, bundle adjust with stricter tolerance
        points3d_with_views, R_mats, t_vecs = do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, kp, K, ftol=1e-1)
    
    av = 0
    for im in resected_imgs:
        p3d, p2d, avg_error, errors = get_reproj_errors(im, points3d_with_views, R_mats[im], t_vecs[im], K, kp, distCoeffs=np.array([]))
        print(f'Average reprojection error on image {im} is {avg_error} pixels')
        av += avg_error
    av = av/len(resected_imgs)
    print(f'Average reprojection error across all {len(resected_imgs)} resected images is {av} pixels')
# Out:
# Unresected image: 19, resected: 18
# rvec: [[-0.34530057]
#  [ 0.12705671]
#  [ 3.23010729]]
#
# tvec: [[-1.86292377]
#  [ 0.01155476]
#  [ 0.38268951]]
# Average error of reprojecting points used to resect image 19 back onto it is: 1.1803941546928645
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 156
# Triangulating: 244 points.
# Average reprojection error for just-triangulated points on image 18 is: 0.39237797524738316 pixels.
# Average reprojection error for just-triangulated points on image 19 is: 0.38098519153962496 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.7266e+02                                    2.03e+05
#        1              3         5.3807e+02      3.46e+01       2.79e+00       4.14e+05
#        2              4         1.5630e+02      3.82e+02       1.32e-01       2.06e+04
#        3              5         1.2549e+02      3.08e+01       5.60e-01       3.47e+04
#        4              6         1.0624e+02      1.93e+01       1.25e+00       1.40e+05
#        5              8         7.3078e+01      3.32e+01       1.36e-01       3.77e+04
#        6              9         6.2780e+01      1.03e+01       5.65e-01       7.05e+04
#        7             10         5.9418e+01      3.36e+00       4.82e-01       1.09e+05
# `ftol` termination condition is satisfied.
# Function evaluations 10, initial cost 5.7266e+02, final cost 5.9418e+01, first-order optimality 1.09e+05.
# Average reprojection error on image 17 is 0.12348554079039877 pixels
# Average reprojection error on image 18 is 0.10852262819047681 pixels
# Average reprojection error on image 19 is 0.1586282979421909 pixels
# Average reprojection error across all 3 resected images is 0.13021215564102215 pixels
# Unresected image: 16, resected: 17
# rvec: [[-0.00374193]
#  [-0.18632044]
#  [-0.08200459]]
#
# tvec: [[ 0.78312141]
#  [-0.03441886]
#  [-0.15292702]]
# Average error of reprojecting points used to resect image 16 back onto it is: 0.627879720536442
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 132
# Triangulating: 175 points.
# Average reprojection error for just-triangulated points on image 16 is: 0.11394407969281328 pixels.
# Average reprojection error for just-triangulated points on image 17 is: 0.10986917663516887 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.9050e+02                                    1.09e+05
#        1              3         1.3676e+02      5.37e+01       2.77e+00       1.11e+05
#        2              5         9.8437e+01      3.83e+01       9.88e-01       1.11e+04
#        3              6         8.5244e+01      1.32e+01       1.95e+00       4.87e+04
#        4              7         7.8520e+01      6.72e+00       1.91e+00       4.25e+04
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 1.9050e+02, final cost 7.8520e+01, first-order optimality 4.25e+04.
# Average reprojection error on image 17 is 0.10653924465038205 pixels
# Average reprojection error on image 18 is 0.08912638113204693 pixels
# Average reprojection error on image 19 is 0.14286424815371734 pixels
# Average reprojection error on image 16 is 0.14342902233355473 pixels
# Average reprojection error across all 4 resected images is 0.12048972406742525 pixels
# Unresected image: 20, resected: 19
# rvec: [[0.01664768]
#  [0.52078136]
#  [0.24291212]]
#
# tvec: [[-2.41129697]
#  [-0.1915915 ]
#  [ 0.2673036 ]]
# Average error of reprojecting points used to resect image 20 back onto it is: 0.38598051682696755
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 190
# Triangulating: 285 points.
# Average reprojection error for just-triangulated points on image 19 is: 42.05213227846042 pixels.
# Average reprojection error for just-triangulated points on image 20 is: 7.429837742905777 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.8677e+05                                    2.04e+07
#        1              2         1.0388e+04      7.76e+05       1.01e+01       1.28e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 7.8677e+05, final cost 1.0388e+04, first-order optimality 1.28e+06.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.0388e+04                                    1.28e+06
#        1              2         9.6481e+02      9.42e+03       3.78e+00       3.07e+05
#        2              3         5.1972e+02      4.45e+02       2.00e+00       5.39e+05
#        3              4         3.0174e+02      2.18e+02       3.95e-02       1.15e+03
#        4              5         3.0168e+02      5.50e-02       3.32e-02       1.24e+03
# `ftol` termination condition is satisfied.
# Function evaluations 5, initial cost 1.0388e+04, final cost 3.0168e+02, first-order optimality 1.24e+03.
# Average reprojection error on image 17 is 0.11247715854566981 pixels
# Average reprojection error on image 18 is 0.11092804306707678 pixels
# Average reprojection error on image 19 is 0.1257973562316152 pixels
# Average reprojection error on image 16 is 0.14011359908207138 pixels
# Average reprojection error on image 20 is 0.16991190577644966 pixels
# Average reprojection error across all 5 resected images is 0.13184561254057656 pixels
# Unresected image: 15, resected: 16
# rvec: [[ 0.56534655]
#  [-0.17246396]
#  [ 2.92328903]]
#
# tvec: [[ 1.5783333 ]
#  [-0.11927542]
#  [ 0.40366683]]
# Average error of reprojecting points used to resect image 15 back onto it is: 0.5914481215530502
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 109
# Triangulating: 157 points.
# Average reprojection error for just-triangulated points on image 15 is: 0.9208354491301446 pixels.
# Average reprojection error for just-triangulated points on image 16 is: 11.238081821547372 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.5793e+04                                    3.46e+06
#        1              2         4.5257e+02      3.53e+04       3.97e+00       1.93e+05
#        2              3         3.3268e+02      1.20e+02       5.75e-01       5.85e+03
#        3              4         3.3258e+02      9.63e-02       1.23e-01       5.55e+02
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 3.5793e+04, final cost 3.3258e+02, first-order optimality 5.55e+02.
# Average reprojection error on image 17 is 0.12677940740830063 pixels
# Average reprojection error on image 18 is 0.1129118034448846 pixels
# Average reprojection error on image 19 is 0.12615086160005498 pixels
# Average reprojection error on image 16 is 0.1208895672251905 pixels
# Average reprojection error on image 20 is 0.17092288468528244 pixels
# Average reprojection error on image 15 is 0.13562281959553898 pixels
# Average reprojection error across all 6 resected images is 0.13221289065987535 pixels
# Unresected image: 21, resected: 20
# rvec: [[ 0.85258429]
#  [ 0.0832961 ]
#  [-2.72689231]]
#
# tvec: [[-3.06651681]
#  [-0.44987799]
#  [ 1.21271265]]
# Average error of reprojecting points used to resect image 21 back onto it is: 0.3860050890929351
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 226
# Triangulating: 270 points.
# Average reprojection error for just-triangulated points on image 20 is: 15.48404017400162 pixels.
# Average reprojection error for just-triangulated points on image 21 is: 3.659633044113547 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.3080e+04                                    5.62e+06
#        1              2         9.0572e+02      9.22e+04       5.34e+00       2.95e+05
#        2              3         3.6438e+02      5.41e+02       9.67e-02       1.23e+03
#        3              4         3.6436e+02      1.33e-02       1.98e-02       1.35e+02
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 9.3080e+04, final cost 3.6436e+02, first-order optimality 1.35e+02.
# Average reprojection error on image 17 is 0.1272919020898059 pixels
# Average reprojection error on image 18 is 0.11429429539667418 pixels
# Average reprojection error on image 19 is 0.13473080007592053 pixels
# Average reprojection error on image 16 is 0.12093761964029717 pixels
# Average reprojection error on image 20 is 0.13085094496934502 pixels
# Average reprojection error on image 15 is 0.1345699531055899 pixels
# Average reprojection error on image 21 is 0.0967396337924156 pixels
# Average reprojection error across all 7 resected images is 0.12277359272429263 pixels
# Unresected image: 14, resected: 15
# rvec: [[-0.00212206]
#  [-0.47618472]
#  [-0.24239258]]
#
# tvec: [[ 2.34399766]
#  [-0.31567887]
#  [ 0.82366871]]
# Average error of reprojecting points used to resect image 14 back onto it is: 0.4597448736315258
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 93
# Triangulating: 137 points.
# Average reprojection error for just-triangulated points on image 14 is: 1.9292724411526985 pixels.
# Average reprojection error for just-triangulated points on image 15 is: 3.4988739937094184 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.8983e+03                                    4.18e+05
#        1              2         3.8435e+02      3.51e+03       4.77e-01       4.97e+03
#        2              3         3.8412e+02      2.32e-01       1.29e-02       4.97e+01
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 3.8983e+03, final cost 3.8412e+02, first-order optimality 4.97e+01.
# Average reprojection error on image 17 is 0.1316124404061934 pixels
# Average reprojection error on image 18 is 0.11498874384084351 pixels
# Average reprojection error on image 19 is 0.13543124182890445 pixels
# Average reprojection error on image 16 is 0.129205065399283 pixels
# Average reprojection error on image 20 is 0.13077604907904117 pixels
# Average reprojection error on image 15 is 0.11272447488794043 pixels
# Average reprojection error on image 21 is 0.09668585861598836 pixels
# Average reprojection error on image 14 is 0.11344520026765184 pixels
# Average reprojection error across all 8 resected images is 0.12060863429073077 pixels
# Unresected image: 22, resected: 21
# rvec: [[-1.97049921]
#  [ 3.74615888]
#  [ 0.17505506]]
#
# tvec: [[-3.66405683]
#  [-0.68724047]
#  [ 1.79298793]]
# Average error of reprojecting points used to resect image 22 back onto it is: 0.3741903128114279
# Fraction of Pnp inliers: 0.9951923076923077 num pts used in Pnp: 208
# Triangulating: 319 points.
# Average reprojection error for just-triangulated points on image 21 is: 3.3793057406492757 pixels.
# Average reprojection error for just-triangulated points on image 22 is: 1.3426938112848965 pixels.
# Average reprojection error on image 17 is 0.1316124404061934 pixels
# Average reprojection error on image 18 is 0.11498874384084351 pixels
# Average reprojection error on image 19 is 0.13543124182890445 pixels
# Average reprojection error on image 16 is 0.129205065399283 pixels
# Average reprojection error on image 20 is 0.13077604907904117 pixels
# Average reprojection error on image 15 is 0.11272447488794043 pixels
# Average reprojection error on image 21 is 1.381539530233926 pixels
# Average reprojection error on image 14 is 0.11344520026765184 pixels
# Average reprojection error on image 22 is 0.9604381610335103 pixels
# Average reprojection error across all 9 resected images is 0.3566845452196994 pixels
# Unresected image: 13, resected: 14
# rvec: [[ 0.00780625]
#  [-0.64016712]
#  [-0.32414236]]
#
# tvec: [[ 2.98595252]
#  [-0.51207864]
#  [ 1.21861813]]
# Average error of reprojecting points used to resect image 13 back onto it is: 0.9731683517529561
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 84
# Triangulating: 104 points.
# Average reprojection error for just-triangulated points on image 13 is: 0.38464104331527815 pixels.
# Average reprojection error for just-triangulated points on image 14 is: 0.7322451294984482 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.2739e+03                                    1.23e+06
#        1              2         4.8169e+02      5.79e+03       1.26e+00       4.56e+04
#        2              3         4.6842e+02      1.33e+01       5.54e-02       3.75e+02
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 6.2739e+03, final cost 4.6842e+02, first-order optimality 3.75e+02.
# Average reprojection error on image 17 is 0.1354322114303018 pixels
# Average reprojection error on image 18 is 0.11702186506616725 pixels
# Average reprojection error on image 19 is 0.13993668957085523 pixels
# Average reprojection error on image 16 is 0.1323996105372358 pixels
# Average reprojection error on image 20 is 0.14183243962310688 pixels
# Average reprojection error on image 15 is 0.12296168976906888 pixels
# Average reprojection error on image 21 is 0.08803667971538648 pixels
# Average reprojection error on image 14 is 0.1038676849295217 pixels
# Average reprojection error on image 22 is 0.10190280039724844 pixels
# Average reprojection error on image 13 is 0.13308929245304682 pixels
# Average reprojection error across all 10 resected images is 0.12164809634919393 pixels
# Unresected image: 23, resected: 22
# rvec: [[0.02954138]
#  [0.94226417]
#  [0.47800141]]
#
# tvec: [[-4.1273858 ]
#  [-0.97127626]
#  [ 2.35884384]]
# Average error of reprojecting points used to resect image 23 back onto it is: 0.33549739105502663
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 236
# Triangulating: 306 points.
# Average reprojection error for just-triangulated points on image 22 is: 0.6184108931236946 pixels.
# Average reprojection error for just-triangulated points on image 23 is: 0.5252237899665498 pixels.
# Average reprojection error on image 17 is 0.1354322114303018 pixels
# Average reprojection error on image 18 is 0.11702186506616725 pixels
# Average reprojection error on image 19 is 0.13993668957085523 pixels
# Average reprojection error on image 16 is 0.1323996105372358 pixels
# Average reprojection error on image 20 is 0.14183243962310688 pixels
# Average reprojection error on image 15 is 0.12296168976906888 pixels
# Average reprojection error on image 21 is 0.08803667971538648 pixels
# Average reprojection error on image 14 is 0.1038676849295217 pixels
# Average reprojection error on image 22 is 0.2916404671130858 pixels
# Average reprojection error on image 13 is 0.13308929245304682 pixels
# Average reprojection error on image 23 is 0.442612295237545 pixels
# Average reprojection error across all 11 resected images is 0.16807553867684744 pixels
# Unresected image: 12, resected: 13
# rvec: [[ 1.60327953]
#  [-1.01769393]
#  [ 2.42120247]]
#
# tvec: [[ 3.56689595]
#  [-0.8069214 ]
#  [ 1.7346649 ]]
# Average error of reprojecting points used to resect image 12 back onto it is: 0.3376904287178234
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 97
# Triangulating: 144 points.
# Average reprojection error for just-triangulated points on image 12 is: 1.492642869510311 pixels.
# Average reprojection error for just-triangulated points on image 13 is: 2.2334201460552903 pixels.
# Average reprojection error on image 17 is 0.1354322114303018 pixels
# Average reprojection error on image 18 is 0.11702186506616725 pixels
# Average reprojection error on image 19 is 0.13993668957085523 pixels
# Average reprojection error on image 16 is 0.1323996105372358 pixels
# Average reprojection error on image 20 is 0.14183243962310688 pixels
# Average reprojection error on image 15 is 0.12296168976906888 pixels
# Average reprojection error on image 21 is 0.08803667971538648 pixels
# Average reprojection error on image 14 is 0.1038676849295217 pixels
# Average reprojection error on image 22 is 0.2916404671130858 pixels
# Average reprojection error on image 13 is 1.0440761687142603 pixels
# Average reprojection error on image 23 is 0.442612295237545 pixels
# Average reprojection error on image 12 is 1.0310126573448484 pixels
# Average reprojection error across all 12 resected images is 0.315902538254282 pixels
# Unresected image: 24, resected: 23
# rvec: [[-0.90038006]
#  [ 3.27109499]
#  [-1.53651132]]
#
# tvec: [[-4.46109601]
#  [-1.31189579]
#  [ 3.01758438]]
# Average error of reprojecting points used to resect image 24 back onto it is: 0.5943760276790543
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 279
# Triangulating: 340 points.
# Average reprojection error for just-triangulated points on image 23 is: 0.2708613943218265 pixels.
# Average reprojection error for just-triangulated points on image 24 is: 0.2770620204947458 pixels.
# Average reprojection error on image 17 is 0.1354322114303018 pixels
# Average reprojection error on image 18 is 0.11702186506616725 pixels
# Average reprojection error on image 19 is 0.13993668957085523 pixels
# Average reprojection error on image 16 is 0.1323996105372358 pixels
# Average reprojection error on image 20 is 0.14183243962310688 pixels
# Average reprojection error on image 15 is 0.12296168976906888 pixels
# Average reprojection error on image 21 is 0.08803667971538648 pixels
# Average reprojection error on image 14 is 0.1038676849295217 pixels
# Average reprojection error on image 22 is 0.2916404671130858 pixels
# Average reprojection error on image 13 is 1.0440761687142603 pixels
# Average reprojection error on image 23 is 0.3764044649525742 pixels
# Average reprojection error on image 12 is 1.0310126573448484 pixels
# Average reprojection error on image 24 is 0.42008400434682863 pixels
# Average reprojection error across all 13 resected images is 0.318823587162557 pixels
# Unresected image: 11, resected: 12
# rvec: [[ 1.28956605]
#  [-0.29958563]
#  [ 2.47225331]]
#
# tvec: [[ 4.07414184]
#  [-1.10052326]
#  [ 2.41600026]]
# Average error of reprojecting points used to resect image 11 back onto it is: 1.2526745726598765
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 102
# Triangulating: 159 points.
# Average reprojection error for just-triangulated points on image 11 is: 0.572597451560212 pixels.
# Average reprojection error for just-triangulated points on image 12 is: 0.5942048683394425 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.2973e+03                                    6.74e+05
#        1              2         7.6890e+02      2.53e+03       1.44e+00       2.05e+05
#        2              3         5.5900e+02      2.10e+02       8.46e-02       4.75e+02
#        3              4         5.5894e+02      5.28e-02       1.02e-01       7.98e+02
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 3.2973e+03, final cost 5.5894e+02, first-order optimality 7.98e+02.
# Average reprojection error on image 17 is 0.13754433015738177 pixels
# Average reprojection error on image 18 is 0.11583630515190331 pixels
# Average reprojection error on image 19 is 0.14216306964021655 pixels
# Average reprojection error on image 16 is 0.13429447056544147 pixels
# Average reprojection error on image 20 is 0.14681303879630125 pixels
# Average reprojection error on image 15 is 0.1312418464025391 pixels
# Average reprojection error on image 21 is 0.10330453832350735 pixels
# Average reprojection error on image 14 is 0.12019017815812781 pixels
# Average reprojection error on image 22 is 0.10108212064760001 pixels
# Average reprojection error on image 13 is 0.10433934584395191 pixels
# Average reprojection error on image 23 is 0.08191391114937116 pixels
# Average reprojection error on image 12 is 0.08730276686655673 pixels
# Average reprojection error on image 24 is 0.0898821781969007 pixels
# Average reprojection error on image 11 is 0.10595399729486236 pixels
# Average reprojection error across all 14 resected images is 0.1144187212281901 pixels
# Unresected image: 25, resected: 24
# rvec: [[ 0.68817317]
#  [ 0.76876058]
#  [-2.61611744]]
#
# tvec: [[-4.66153607]
#  [-1.66111223]
#  [ 3.63874387]]
# Average error of reprojecting points used to resect image 25 back onto it is: 0.33809953764540923
# Fraction of Pnp inliers: 0.9968253968253968 num pts used in Pnp: 315
# Triangulating: 296 points.
# Average reprojection error for just-triangulated points on image 24 is: 3.912533034149002 pixels.
# Average reprojection error for just-triangulated points on image 25 is: 1.58205508170331 pixels.
# Average reprojection error on image 17 is 0.13754433015738177 pixels
# Average reprojection error on image 18 is 0.11583630515190331 pixels
# Average reprojection error on image 19 is 0.14216306964021655 pixels
# Average reprojection error on image 16 is 0.13429447056544147 pixels
# Average reprojection error on image 20 is 0.14681303879630125 pixels
# Average reprojection error on image 15 is 0.1312418464025391 pixels
# Average reprojection error on image 21 is 0.10330453832350735 pixels
# Average reprojection error on image 14 is 0.12019017815812781 pixels
# Average reprojection error on image 22 is 0.10108212064760001 pixels
# Average reprojection error on image 13 is 0.10433934584395191 pixels
# Average reprojection error on image 23 is 0.08191391114937116 pixels
# Average reprojection error on image 12 is 0.08730276686655673 pixels
# Average reprojection error on image 24 is 1.3264992856961597 pixels
# Average reprojection error on image 11 is 0.10595399729486236 pixels
# Average reprojection error on image 25 is 0.9407359386947393 pixels
# Average reprojection error across all 15 resected images is 0.25194767622591063 pixels
# Unresected image: 10, resected: 11
# rvec: [[-0.01742876]
#  [-1.0862057 ]
#  [-0.5486377 ]]
#
# tvec: [[ 4.3567829 ]
#  [-1.47323027]
#  [ 2.95991421]]
# Average error of reprojecting points used to resect image 10 back onto it is: 0.35480693972190325
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 110
# Triangulating: 128 points.
# Average reprojection error for just-triangulated points on image 10 is: 2.170703873994671 pixels.
# Average reprojection error for just-triangulated points on image 11 is: 8.347036542317001 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.9221e+04                                    1.39e+06
#        1              2         9.2465e+02      1.83e+04       2.29e+00       8.80e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 1.9221e+04, final cost 9.2465e+02, first-order optimality 8.80e+04.
# Average reprojection error on image 17 is 0.13796364368343206 pixels
# Average reprojection error on image 18 is 0.11667319530914383 pixels
# Average reprojection error on image 19 is 0.14290106383025541 pixels
# Average reprojection error on image 16 is 0.13553695841571 pixels
# Average reprojection error on image 20 is 0.14841980699331364 pixels
# Average reprojection error on image 15 is 0.13429618276574917 pixels
# Average reprojection error on image 21 is 0.10693011164966505 pixels
# Average reprojection error on image 14 is 0.1210483859123733 pixels
# Average reprojection error on image 22 is 0.10766455522560145 pixels
# Average reprojection error on image 13 is 0.1143128314839365 pixels
# Average reprojection error on image 23 is 0.09849493541395979 pixels
# Average reprojection error on image 12 is 0.11360862239635854 pixels
# Average reprojection error on image 24 is 0.10304642760771895 pixels
# Average reprojection error on image 11 is 0.383534523493411 pixels
# Average reprojection error on image 25 is 0.1344295819958098 pixels
# Average reprojection error on image 10 is 0.39149168223284503 pixels
# Average reprojection error across all 16 resected images is 0.15564703177558023 pixels
# Unresected image: 26, resected: 25
# rvec: [[ 1.5794205 ]
#  [-0.15396782]
#  [-1.84956037]]
#
# tvec: [[-4.73805089]
#  [-2.05057508]
#  [ 4.39931439]]
# Average error of reprojecting points used to resect image 26 back onto it is: 0.7048254702149176
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 281
# Triangulating: 247 points.
# Average reprojection error for just-triangulated points on image 25 is: 0.30716052836987084 pixels.
# Average reprojection error for just-triangulated points on image 26 is: 0.2762980169856344 pixels.
# Average reprojection error on image 17 is 0.13796364368343206 pixels
# Average reprojection error on image 18 is 0.11667319530914383 pixels
# Average reprojection error on image 19 is 0.14290106383025541 pixels
# Average reprojection error on image 16 is 0.13553695841571 pixels
# Average reprojection error on image 20 is 0.14841980699331364 pixels
# Average reprojection error on image 15 is 0.13429618276574917 pixels
# Average reprojection error on image 21 is 0.10693011164966505 pixels
# Average reprojection error on image 14 is 0.1210483859123733 pixels
# Average reprojection error on image 22 is 0.10766455522560145 pixels
# Average reprojection error on image 13 is 0.1143128314839365 pixels
# Average reprojection error on image 23 is 0.09849493541395979 pixels
# Average reprojection error on image 12 is 0.11360862239635854 pixels
# Average reprojection error on image 24 is 0.10304642760771895 pixels
# Average reprojection error on image 11 is 0.383534523493411 pixels
# Average reprojection error on image 25 is 0.1841551574671304 pixels
# Average reprojection error on image 10 is 0.39149168223284503 pixels
# Average reprojection error on image 26 is 0.504359029026192 pixels
# Average reprojection error across all 17 resected images is 0.179084536053341 pixels
# Unresected image: 9, resected: 10
# rvec: [[-0.47829663]
#  [-1.43690159]
#  [-0.31173738]]
#
# tvec: [[ 4.58353476]
#  [-1.73837855]
#  [ 3.69039963]]
# Average error of reprojecting points used to resect image 9 back onto it is: 0.8163251447251157
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 111
# Triangulating: 156 points.
# Average reprojection error for just-triangulated points on image 9 is: 1.7817843561632236 pixels.
# Average reprojection error for just-triangulated points on image 10 is: 5.682774684541939 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.3719e+03                                    6.18e+05
#        1              2         1.3219e+03      7.05e+03       1.61e+00       1.90e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 8.3719e+03, final cost 1.3219e+03, first-order optimality 1.90e+05.
# Average reprojection error on image 17 is 0.138018836813045 pixels
# Average reprojection error on image 18 is 0.11719600152255133 pixels
# Average reprojection error on image 19 is 0.1431960496186335 pixels
# Average reprojection error on image 16 is 0.1356030997759703 pixels
# Average reprojection error on image 20 is 0.14987332766067105 pixels
# Average reprojection error on image 15 is 0.13491080049116597 pixels
# Average reprojection error on image 21 is 0.10892494711709808 pixels
# Average reprojection error on image 14 is 0.12103041733677919 pixels
# Average reprojection error on image 22 is 0.11090786247806123 pixels
# Average reprojection error on image 13 is 0.11590767794786218 pixels
# Average reprojection error on image 23 is 0.10479529749337019 pixels
# Average reprojection error on image 12 is 0.1133685078780457 pixels
# Average reprojection error on image 24 is 0.10263838675807563 pixels
# Average reprojection error on image 11 is 0.20020350082480012 pixels
# Average reprojection error on image 25 is 0.10521913423477092 pixels
# Average reprojection error on image 10 is 0.20831725746381688 pixels
# Average reprojection error on image 26 is 0.16034463252420555 pixels
# Average reprojection error on image 9 is 0.9486030672769291 pixels
# Average reprojection error across all 18 resected images is 0.17883660028976958 pixels
# Unresected image: 27, resected: 26
# rvec: [[0.0229136 ]
#  [1.53452758]
#  [0.78748201]]
#
# tvec: [[-4.69383668]
#  [-2.39387444]
#  [ 5.05613885]]
# Average error of reprojecting points used to resect image 27 back onto it is: 0.35670818386127195
# Fraction of Pnp inliers: 0.9953051643192489 num pts used in Pnp: 213
# Triangulating: 190 points.
# Average reprojection error for just-triangulated points on image 26 is: 3.071961532687169 pixels.
# Average reprojection error for just-triangulated points on image 27 is: 2.9269642637006164 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.6163e+03                                    1.14e+06
#        1              2         9.6245e+02      6.65e+03       3.11e-01       2.07e+04
#        2              3         9.5879e+02      3.66e+00       1.86e-02       1.70e+02
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 7.6163e+03, final cost 9.5879e+02, first-order optimality 1.70e+02.
# Average reprojection error on image 17 is 0.13779884208224613 pixels
# Average reprojection error on image 18 is 0.11756479859088387 pixels
# Average reprojection error on image 19 is 0.1435721577898208 pixels
# Average reprojection error on image 16 is 0.13552228899996405 pixels
# Average reprojection error on image 20 is 0.15204694997959928 pixels
# Average reprojection error on image 15 is 0.13490090843224234 pixels
# Average reprojection error on image 21 is 0.11027926112062966 pixels
# Average reprojection error on image 14 is 0.12072215968041773 pixels
# Average reprojection error on image 22 is 0.11200605953972748 pixels
# Average reprojection error on image 13 is 0.11540752334868579 pixels
# Average reprojection error on image 23 is 0.1077986479391509 pixels
# Average reprojection error on image 12 is 0.11365901240594285 pixels
# Average reprojection error on image 24 is 0.10742092746084672 pixels
# Average reprojection error on image 11 is 0.20072519533442598 pixels
# Average reprojection error on image 25 is 0.11379906913192744 pixels
# Average reprojection error on image 10 is 0.1976341888133703 pixels
# Average reprojection error on image 26 is 0.10256718477667362 pixels
# Average reprojection error on image 9 is 0.1161514802431921 pixels
# Average reprojection error on image 27 is 0.11920028246657124 pixels
# Average reprojection error across all 19 resected images is 0.12940931253349044 pixels
# Unresected image: 8, resected: 9
# rvec: [[-0.02154786]
#  [-1.41203195]
#  [-0.70639349]]
#
# tvec: [[ 4.66972079]
#  [-2.18670115]
#  [ 4.49869837]]
# Average error of reprojecting points used to resect image 8 back onto it is: 0.36470279762749436
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 114
# Triangulating: 204 points.
# Average reprojection error for just-triangulated points on image 8 is: 6.321438953577412 pixels.
# Average reprojection error for just-triangulated points on image 9 is: 15.114872860933183 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.5034e+04                                    2.41e+06
#        1              2         1.1543e+03      6.39e+04       3.64e+00       1.94e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 6.5034e+04, final cost 1.1543e+03, first-order optimality 1.94e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.1543e+03                                    1.94e+05
#        1              2         9.9256e+02      1.62e+02       3.49e-01       7.06e+03
#        2              3         9.9239e+02      1.64e-01       1.53e-02       5.79e+01
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.1543e+03, final cost 9.9239e+02, first-order optimality 5.79e+01.
# Average reprojection error on image 17 is 0.13780515512333816 pixels
# Average reprojection error on image 18 is 0.1176259504501542 pixels
# Average reprojection error on image 19 is 0.1436200336027655 pixels
# Average reprojection error on image 16 is 0.1355827811255686 pixels
# Average reprojection error on image 20 is 0.15209532183180996 pixels
# Average reprojection error on image 15 is 0.13495366030278286 pixels
# Average reprojection error on image 21 is 0.11036904142193366 pixels
# Average reprojection error on image 14 is 0.12050828010966708 pixels
# Average reprojection error on image 22 is 0.11206572034503753 pixels
# Average reprojection error on image 13 is 0.11535041522216206 pixels
# Average reprojection error on image 23 is 0.107853252822465 pixels
# Average reprojection error on image 12 is 0.11517000474360037 pixels
# Average reprojection error on image 24 is 0.1074243804497868 pixels
# Average reprojection error on image 11 is 0.20264262764139335 pixels
# Average reprojection error on image 25 is 0.11381246721766552 pixels
# Average reprojection error on image 10 is 0.2071213771574033 pixels
# Average reprojection error on image 26 is 0.10258731592375217 pixels
# Average reprojection error on image 9 is 0.10679215428507662 pixels
# Average reprojection error on image 27 is 0.11911627552541756 pixels
# Average reprojection error on image 8 is 0.12011732912101088 pixels
# Average reprojection error across all 20 resected images is 0.12913067722113955 pixels
# Unresected image: 28, resected: 27
# rvec: [[0.01293768]
#  [1.7002074 ]
#  [0.84933435]]
#
# tvec: [[-4.50339151]
#  [-2.75048643]
#  [ 5.82197891]]
# Average error of reprojecting points used to resect image 28 back onto it is: 0.2844951771850502
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 152
# Triangulating: 181 points.
# Average reprojection error for just-triangulated points on image 27 is: 0.9349505411064918 pixels.
# Average reprojection error for just-triangulated points on image 28 is: 0.42749071625741675 pixels.
# Average reprojection error on image 17 is 0.13780515512333816 pixels
# Average reprojection error on image 18 is 0.1176259504501542 pixels
# Average reprojection error on image 19 is 0.1436200336027655 pixels
# Average reprojection error on image 16 is 0.1355827811255686 pixels
# Average reprojection error on image 20 is 0.15209532183180996 pixels
# Average reprojection error on image 15 is 0.13495366030278286 pixels
# Average reprojection error on image 21 is 0.11036904142193366 pixels
# Average reprojection error on image 14 is 0.12050828010966708 pixels
# Average reprojection error on image 22 is 0.11206572034503753 pixels
# Average reprojection error on image 13 is 0.11535041522216206 pixels
# Average reprojection error on image 23 is 0.107853252822465 pixels
# Average reprojection error on image 12 is 0.11517000474360037 pixels
# Average reprojection error on image 24 is 0.1074243804497868 pixels
# Average reprojection error on image 11 is 0.20264262764139335 pixels
# Average reprojection error on image 25 is 0.11381246721766552 pixels
# Average reprojection error on image 10 is 0.2071213771574033 pixels
# Average reprojection error on image 26 is 0.10258731592375217 pixels
# Average reprojection error on image 9 is 0.10679215428507662 pixels
# Average reprojection error on image 27 is 0.3719690187962642 pixels
# Average reprojection error on image 8 is 0.12011732912101088 pixels
# Average reprojection error on image 28 is 0.36221947920339115 pixels
# Average reprojection error across all 21 resected images is 0.15227075080462044 pixels
# Unresected image: 7, resected: 8
# rvec: [[-0.03255441]
#  [-1.56818964]
#  [-0.78113886]]
#
# tvec: [[ 4.58202246]
#  [-2.55401458]
#  [ 5.24435629]]
# Average error of reprojecting points used to resect image 7 back onto it is: 0.3624701052553385
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 108
# Triangulating: 155 points.
# Average reprojection error for just-triangulated points on image 7 is: 0.16389225334091173 pixels.
# Average reprojection error for just-triangulated points on image 8 is: 1.446165427548148 pixels.
# Average reprojection error on image 17 is 0.13780515512333816 pixels
# Average reprojection error on image 18 is 0.1176259504501542 pixels
# Average reprojection error on image 19 is 0.1436200336027655 pixels
# Average reprojection error on image 16 is 0.1355827811255686 pixels
# Average reprojection error on image 20 is 0.15209532183180996 pixels
# Average reprojection error on image 15 is 0.13495366030278286 pixels
# Average reprojection error on image 21 is 0.11036904142193366 pixels
# Average reprojection error on image 14 is 0.12050828010966708 pixels
# Average reprojection error on image 22 is 0.11206572034503753 pixels
# Average reprojection error on image 13 is 0.11535041522216206 pixels
# Average reprojection error on image 23 is 0.107853252822465 pixels
# Average reprojection error on image 12 is 0.11517000474360037 pixels
# Average reprojection error on image 24 is 0.1074243804497868 pixels
# Average reprojection error on image 11 is 0.20264262764139335 pixels
# Average reprojection error on image 25 is 0.11381246721766552 pixels
# Average reprojection error on image 10 is 0.2071213771574033 pixels
# Average reprojection error on image 26 is 0.10258731592375217 pixels
# Average reprojection error on image 9 is 0.10679215428507662 pixels
# Average reprojection error on image 27 is 0.3719690187962642 pixels
# Average reprojection error on image 8 is 0.5555780394095836 pixels
# Average reprojection error on image 28 is 0.36221947920339115 pixels
# Average reprojection error on image 7 is 0.24543753093314674 pixels
# Average reprojection error across all 22 resected images is 0.17629927309630675 pixels
# Unresected image: 29, resected: 28
# rvec: [[-0.33535484]
#  [ 1.48149722]
#  [-2.54310059]]
#
# tvec: [[-4.16457739]
#  [-3.07912251]
#  [ 6.55391326]]
# Average error of reprojecting points used to resect image 29 back onto it is: 0.7680879140816258
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 102
# Triangulating: 163 points.
# Average reprojection error for just-triangulated points on image 28 is: 0.20626957330159781 pixels.
# Average reprojection error for just-triangulated points on image 29 is: 0.22116356204904725 pixels.
# Average reprojection error on image 17 is 0.13780515512333816 pixels
# Average reprojection error on image 18 is 0.1176259504501542 pixels
# Average reprojection error on image 19 is 0.1436200336027655 pixels
# Average reprojection error on image 16 is 0.1355827811255686 pixels
# Average reprojection error on image 20 is 0.15209532183180996 pixels
# Average reprojection error on image 15 is 0.13495366030278286 pixels
# Average reprojection error on image 21 is 0.11036904142193366 pixels
# Average reprojection error on image 14 is 0.12050828010966708 pixels
# Average reprojection error on image 22 is 0.11206572034503753 pixels
# Average reprojection error on image 13 is 0.11535041522216206 pixels
# Average reprojection error on image 23 is 0.107853252822465 pixels
# Average reprojection error on image 12 is 0.11517000474360037 pixels
# Average reprojection error on image 24 is 0.1074243804497868 pixels
# Average reprojection error on image 11 is 0.20264262764139335 pixels
# Average reprojection error on image 25 is 0.11381246721766552 pixels
# Average reprojection error on image 10 is 0.2071213771574033 pixels
# Average reprojection error on image 26 is 0.10258731592375217 pixels
# Average reprojection error on image 9 is 0.10679215428507662 pixels
# Average reprojection error on image 27 is 0.3719690187962642 pixels
# Average reprojection error on image 8 is 0.5555780394095836 pixels
# Average reprojection error on image 28 is 0.3109698125461486 pixels
# Average reprojection error on image 7 is 0.24543753093314674 pixels
# Average reprojection error on image 29 is 0.4316778409445702 pixels
# Average reprojection error across all 23 resected images is 0.18517444271330766 pixels
# Unresected image: 6, resected: 7
# rvec: [[-0.03919292]
#  [-1.71611103]
#  [-0.86270461]]
#
# tvec: [[ 4.39516671]
#  [-2.85331391]
#  [ 5.90969274]]
# Average error of reprojecting points used to resect image 6 back onto it is: 1.2506623784047501
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 113
# Triangulating: 243 points.
# Average reprojection error for just-triangulated points on image 6 is: 0.23904727153160318 pixels.
# Average reprojection error for just-triangulated points on image 7 is: 0.22434138764447778 pixels.
# Average reprojection error on image 17 is 0.13780515512333816 pixels
# Average reprojection error on image 18 is 0.1176259504501542 pixels
# Average reprojection error on image 19 is 0.1436200336027655 pixels
# Average reprojection error on image 16 is 0.1355827811255686 pixels
# Average reprojection error on image 20 is 0.15209532183180996 pixels
# Average reprojection error on image 15 is 0.13495366030278286 pixels
# Average reprojection error on image 21 is 0.11036904142193366 pixels
# Average reprojection error on image 14 is 0.12050828010966708 pixels
# Average reprojection error on image 22 is 0.11206572034503753 pixels
# Average reprojection error on image 13 is 0.11535041522216206 pixels
# Average reprojection error on image 23 is 0.107853252822465 pixels
# Average reprojection error on image 12 is 0.11517000474360037 pixels
# Average reprojection error on image 24 is 0.1074243804497868 pixels
# Average reprojection error on image 11 is 0.20264262764139335 pixels
# Average reprojection error on image 25 is 0.11381246721766552 pixels
# Average reprojection error on image 10 is 0.2071213771574033 pixels
# Average reprojection error on image 26 is 0.10258731592375217 pixels
# Average reprojection error on image 9 is 0.10679215428507662 pixels
# Average reprojection error on image 27 is 0.3719690187962642 pixels
# Average reprojection error on image 8 is 0.5555780394095836 pixels
# Average reprojection error on image 28 is 0.3109698125461486 pixels
# Average reprojection error on image 7 is 0.2353063791166516 pixels
# Average reprojection error on image 29 is 0.4316778409445702 pixels
# Average reprojection error on image 6 is 0.5601498194997432 pixels
# Average reprojection error across all 24 resected images is 0.20037628542038846 pixels
# Unresected image: 30, resected: 29
# rvec: [[-0.63958662]
#  [-1.93903135]
#  [-0.62626962]]
#
# tvec: [[-3.66301014]
#  [-3.42002179]
#  [ 7.17882947]]
# Average error of reprojecting points used to resect image 30 back onto it is: 1.1956122948488082
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 80
# Triangulating: 135 points.
# Average reprojection error for just-triangulated points on image 29 is: 0.10532640633147507 pixels.
# Average reprojection error for just-triangulated points on image 30 is: 0.10693985618595876 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.6540e+03                                    1.65e+05
#        1              2         1.2982e+03      1.36e+03       7.41e-01       8.70e+04
#        2              3         1.1339e+03      1.64e+02       3.80e-02       2.94e+02
#        3              4         1.1338e+03      5.10e-02       2.51e-02       6.28e+02
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.6540e+03, final cost 1.1338e+03, first-order optimality 6.28e+02.
# Average reprojection error on image 17 is 0.13775527639488225 pixels
# Average reprojection error on image 18 is 0.11737923787205849 pixels
# Average reprojection error on image 19 is 0.14354410401655376 pixels
# Average reprojection error on image 16 is 0.135477530945298 pixels
# Average reprojection error on image 20 is 0.15349656272357576 pixels
# Average reprojection error on image 15 is 0.1343851044695728 pixels
# Average reprojection error on image 21 is 0.1117319343048707 pixels
# Average reprojection error on image 14 is 0.12043406888152695 pixels
# Average reprojection error on image 22 is 0.11375347895810078 pixels
# Average reprojection error on image 13 is 0.1147484639533832 pixels
# Average reprojection error on image 23 is 0.109708155784392 pixels
# Average reprojection error on image 12 is 0.11574739774949808 pixels
# Average reprojection error on image 24 is 0.10944291495571598 pixels
# Average reprojection error on image 11 is 0.2056784155856946 pixels
# Average reprojection error on image 25 is 0.11785537984951427 pixels
# Average reprojection error on image 10 is 0.2106139995607907 pixels
# Average reprojection error on image 26 is 0.11105076561961856 pixels
# Average reprojection error on image 9 is 0.12496708739666992 pixels
# Average reprojection error on image 27 is 0.11316932045849266 pixels
# Average reprojection error on image 8 is 0.11649542876519826 pixels
# Average reprojection error on image 28 is 0.1132636788487811 pixels
# Average reprojection error on image 7 is 0.09401276377756798 pixels
# Average reprojection error on image 29 is 0.10166951056372203 pixels
# Average reprojection error on image 6 is 0.10904101837654304 pixels
# Average reprojection error on image 30 is 0.11510053232744141 pixels
# Average reprojection error across all 25 resected images is 0.12602088528557853 pixels
# Unresected image: 5, resected: 6
# rvec: [[0.27326412]
#  [1.66223514]
#  [4.10495548]]
#
# tvec: [[ 4.00134605]
#  [-3.24030368]
#  [ 6.59676797]]
# Average error of reprojecting points used to resect image 5 back onto it is: 0.33445794243169474
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 147
# Triangulating: 198 points.
# Average reprojection error for just-triangulated points on image 5 is: 3.3818945780153045 pixels.
# Average reprojection error for just-triangulated points on image 6 is: 3.550647214776022 pixels.
# Average reprojection error on image 17 is 0.13775527639488225 pixels
# Average reprojection error on image 18 is 0.11737923787205849 pixels
# Average reprojection error on image 19 is 0.14354410401655376 pixels
# Average reprojection error on image 16 is 0.135477530945298 pixels
# Average reprojection error on image 20 is 0.15349656272357576 pixels
# Average reprojection error on image 15 is 0.1343851044695728 pixels
# Average reprojection error on image 21 is 0.1117319343048707 pixels
# Average reprojection error on image 14 is 0.12043406888152695 pixels
# Average reprojection error on image 22 is 0.11375347895810078 pixels
# Average reprojection error on image 13 is 0.1147484639533832 pixels
# Average reprojection error on image 23 is 0.109708155784392 pixels
# Average reprojection error on image 12 is 0.11574739774949808 pixels
# Average reprojection error on image 24 is 0.10944291495571598 pixels
# Average reprojection error on image 11 is 0.2056784155856946 pixels
# Average reprojection error on image 25 is 0.11785537984951427 pixels
# Average reprojection error on image 10 is 0.2106139995607907 pixels
# Average reprojection error on image 26 is 0.11105076561961856 pixels
# Average reprojection error on image 9 is 0.12496708739666992 pixels
# Average reprojection error on image 27 is 0.11316932045849266 pixels
# Average reprojection error on image 8 is 0.11649542876519826 pixels
# Average reprojection error on image 28 is 0.1132636788487811 pixels
# Average reprojection error on image 7 is 0.09401276377756798 pixels
# Average reprojection error on image 29 is 0.10166951056372203 pixels
# Average reprojection error on image 6 is 1.3390735578839388 pixels
# Average reprojection error on image 30 is 0.11510053232744141 pixels
# Average reprojection error on image 5 is 2.0874418852147922 pixels
# Average reprojection error across all 26 resected images is 0.24876909834083274 pixels
# Unresected image: 31, resected: 30
# rvec: [[0.02809729]
#  [2.15114243]
#  [1.0934934 ]]
#
# tvec: [[-3.19511473]
#  [-3.67196714]
#  [ 7.58144312]]
# Average error of reprojecting points used to resect image 31 back onto it is: 0.4451896516644679
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 40
# Triangulating: 148 points.
# Average reprojection error for just-triangulated points on image 30 is: 9.06048442844305 pixels.
# Average reprojection error for just-triangulated points on image 31 is: 0.48247621580878997 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.1618e+04                                    1.52e+06
#        1              2         1.2436e+03      3.04e+04       2.75e+00       5.27e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 3.1618e+04, final cost 1.2436e+03, first-order optimality 5.27e+04.
# Average reprojection error on image 17 is 0.13756411402056415 pixels
# Average reprojection error on image 18 is 0.11731605762416228 pixels
# Average reprojection error on image 19 is 0.1435580504074775 pixels
# ...
# Average reprojection error on image 19 is 0.1435580504074775 pixels
# Average reprojection error on image 16 is 0.13534987421428837 pixels
# Average reprojection error on image 20 is 0.15360091645409096 pixels
# Average reprojection error on image 15 is 0.13414592605326559 pixels
# Average reprojection error on image 21 is 0.11164104151634303 pixels
# Average reprojection error on image 14 is 0.12032534819487839 pixels
# Average reprojection error on image 22 is 0.11369094881747166 pixels
# Average reprojection error on image 13 is 0.11457121316623611 pixels
# Average reprojection error on image 23 is 0.10976412633764109 pixels
# Average reprojection error on image 12 is 0.11582609859194526 pixels
# Average reprojection error on image 24 is 0.10933537005638648 pixels
# Average reprojection error on image 11 is 0.20638552240525873 pixels
# Average reprojection error on image 25 is 0.11787260953182749 pixels
# Average reprojection error on image 10 is 0.210257894572986 pixels
# Average reprojection error on image 26 is 0.11098502666235321 pixels
# Average reprojection error on image 9 is 0.12586372712989527 pixels
# Average reprojection error on image 27 is 0.11350441113561956 pixels
# Average reprojection error on image 8 is 0.11969404132184572 pixels
# Average reprojection error on image 28 is 0.11463442126481724 pixels
# Average reprojection error on image 7 is 0.10918436817872679 pixels
# Average reprojection error on image 29 is 0.10985650675634819 pixels
# Average reprojection error on image 6 is 0.09939385013372212 pixels
# Average reprojection error on image 30 is 0.22155509254049596 pixels
# Average reprojection error on image 5 is 0.4775341919909416 pixels
# Average reprojection error on image 31 is 1.3996825190997377 pixels
# Average reprojection error on image 4 is 0.33068315617816724 pixels
# Average reprojection error on image 32 is 0.5450347855755941 pixels
# Average reprojection error on image 3 is 0.5777864329850542 pixels
# Average reprojection error on image 33 is 0.582572069702258 pixels
# Average reprojection error on image 2 is 0.8697857424534349 pixels
# Average reprojection error across all 32 resected images is 0.2518423579710573 pixels
# Unresected image: 34, resected: 33
# rvec: [[0.02886727]
#  [2.46618138]
#  [1.3553222 ]]
#
# tvec: [[-1.04976437]
#  [-4.22852735]
#  [ 8.49802808]]
# Average error of reprojecting points used to resect image 34 back onto it is: 1.8337274984151888
# Fraction of Pnp inliers: 0.9398496240601504 num pts used in Pnp: 133
# Triangulating: 198 points.
# Average reprojection error for just-triangulated points on image 33 is: 0.218105590865746 pixels.
# Average reprojection error for just-triangulated points on image 34 is: 0.20770841394980136 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.7308e+03                                    3.78e+05
#        1              2         2.6236e+03      4.11e+03       1.66e+00       2.68e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 6.7308e+03, final cost 2.6236e+03, first-order optimality 2.68e+05.
# Average reprojection error on image 17 is 0.13857175841215416 pixels
# Average reprojection error on image 18 is 0.11740584635364473 pixels
# Average reprojection error on image 19 is 0.14410067508299254 pixels
# Average reprojection error on image 16 is 0.1352859490431871 pixels
# Average reprojection error on image 20 is 0.153309278444284 pixels
# Average reprojection error on image 15 is 0.134116705796215 pixels
# Average reprojection error on image 21 is 0.11232228881829609 pixels
# Average reprojection error on image 14 is 0.12137471319566692 pixels
# Average reprojection error on image 22 is 0.11520005792155211 pixels
# Average reprojection error on image 13 is 0.11730674684488125 pixels
# Average reprojection error on image 23 is 0.1160265683250936 pixels
# Average reprojection error on image 12 is 0.12408792156185525 pixels
# Average reprojection error on image 24 is 0.12236257229346381 pixels
# Average reprojection error on image 11 is 0.23062790363423585 pixels
# Average reprojection error on image 25 is 0.13229257481080164 pixels
# Average reprojection error on image 10 is 0.2638715776131695 pixels
# Average reprojection error on image 26 is 0.1258863336045306 pixels
# Average reprojection error on image 9 is 0.2553811636250447 pixels
# Average reprojection error on image 27 is 0.12725592550452033 pixels
# Average reprojection error on image 8 is 0.2569649164428897 pixels
# Average reprojection error on image 28 is 0.1327091052168196 pixels
# Average reprojection error on image 7 is 0.2647705155673963 pixels
# Average reprojection error on image 29 is 0.14017782098038836 pixels
# Average reprojection error on image 6 is 0.2974387345153325 pixels
# Average reprojection error on image 30 is 0.1675825438348241 pixels
# Average reprojection error on image 5 is 0.38348631466794847 pixels
# Average reprojection error on image 31 is 0.25642093554258016 pixels
# Average reprojection error on image 4 is 0.3446651928558562 pixels
# Average reprojection error on image 32 is 0.43129511044799484 pixels
# Average reprojection error on image 3 is 0.3204731450697579 pixels
# Average reprojection error on image 33 is 0.397949410601329 pixels
# Average reprojection error on image 2 is 0.32683021617010466 pixels
# Average reprojection error on image 34 is 0.987055558559905 pixels
# Average reprojection error across all 33 resected images is 0.22710927519268834 pixels
# Unresected image: 1, resected: 2
# rvec: [[-0.05088212]
#  [-2.47324932]
#  [-1.29767032]]
#
# tvec: [[ 1.63119318]
#  [-4.15760546]
#  [ 8.36389698]]
# Average error of reprojecting points used to resect image 1 back onto it is: 0.6292777235873226
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 248
# Triangulating: 290 points.
# Average reprojection error for just-triangulated points on image 1 is: 0.9086069428596576 pixels.
# Average reprojection error for just-triangulated points on image 2 is: 13.270460314115484 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.1196e+04                                    5.77e+06
#        1              2         2.0537e+03      8.91e+04       7.58e+00       3.97e+05
#        2              3         1.6096e+03      4.44e+02       5.37e-01       5.04e+03
#        3              5         1.6090e+03      5.42e-01       4.59e-02       2.05e+03
# `ftol` termination condition is satisfied.
# Function evaluations 5, initial cost 9.1196e+04, final cost 1.6090e+03, first-order optimality 2.05e+03.
# Average reprojection error on image 17 is 0.13798703333017825 pixels
# Average reprojection error on image 18 is 0.11713798909135431 pixels
# Average reprojection error on image 19 is 0.14369376846000448 pixels
# Average reprojection error on image 16 is 0.13500232796024758 pixels
# Average reprojection error on image 20 is 0.15358528871033306 pixels
# Average reprojection error on image 15 is 0.13393842827634647 pixels
# Average reprojection error on image 21 is 0.11134332380502907 pixels
# Average reprojection error on image 14 is 0.1210560451383802 pixels
# Average reprojection error on image 22 is 0.11369208125129851 pixels
# Average reprojection error on image 13 is 0.1152614779098848 pixels
# Average reprojection error on image 23 is 0.1098179977681107 pixels
# Average reprojection error on image 12 is 0.11627406257576274 pixels
# Average reprojection error on image 24 is 0.10941386279884127 pixels
# Average reprojection error on image 11 is 0.20791105090257592 pixels
# Average reprojection error on image 25 is 0.11806899801660098 pixels
# Average reprojection error on image 10 is 0.21102789223343923 pixels
# Average reprojection error on image 26 is 0.1109949256053368 pixels
# Average reprojection error on image 9 is 0.1281016120868864 pixels
# Average reprojection error on image 27 is 0.11421158180474585 pixels
# Average reprojection error on image 8 is 0.12330154042977698 pixels
# Average reprojection error on image 28 is 0.1176097802539321 pixels
# Average reprojection error on image 7 is 0.12298190071342108 pixels
# Average reprojection error on image 29 is 0.12015052246784318 pixels
# Average reprojection error on image 6 is 0.12653492735556882 pixels
# Average reprojection error on image 30 is 0.1447962026926281 pixels
# Average reprojection error on image 5 is 0.11757011627884134 pixels
# Average reprojection error on image 31 is 0.20357746402722277 pixels
# Average reprojection error on image 4 is 0.1145440001568904 pixels
# Average reprojection error on image 32 is 0.1945517821848491 pixels
# Average reprojection error on image 3 is 0.11836706652137613 pixels
# Average reprojection error on image 33 is 0.14136768168560962 pixels
# Average reprojection error on image 2 is 0.10419615133228373 pixels
# Average reprojection error on image 34 is 0.15717526498387735 pixels
# Average reprojection error on image 1 is 0.12276339464290847 pixels
# Average reprojection error across all 34 resected images is 0.13347081010154074 pixels
# Unresected image: 35, resected: 34
# rvec: [[  53.23213124]
#  [-239.62031323]
#  [  79.03811775]]
#
# tvec: [[ 0.16101716]
#  [-4.12190933]
#  [ 8.90747504]]
# Average error of reprojecting points used to resect image 35 back onto it is: 0.6967872586367685
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 165
# Triangulating: 274 points.
# Average reprojection error for just-triangulated points on image 34 is: 6.804731862818666 pixels.
# Average reprojection error for just-triangulated points on image 35 is: 3.46571183507069 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.6035e+04                                    1.82e+06
#        1              2         1.1766e+04      1.43e+04       1.34e+00       2.96e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.6035e+04, final cost 1.1766e+04, first-order optimality 2.96e+06.
# Average reprojection error on image 17 is 0.13789785975182722 pixels
# Average reprojection error on image 18 is 0.11701613282192827 pixels
# Average reprojection error on image 19 is 0.14353410368550792 pixels
# Average reprojection error on image 16 is 0.13488638553934967 pixels
# Average reprojection error on image 20 is 0.15363514673513184 pixels
# Average reprojection error on image 15 is 0.13394828416995083 pixels
# Average reprojection error on image 21 is 0.11086615101856084 pixels
# Average reprojection error on image 14 is 0.12109290785384713 pixels
# Average reprojection error on image 22 is 0.11383127605343407 pixels
# Average reprojection error on image 13 is 0.11543783219774723 pixels
# Average reprojection error on image 23 is 0.10954395131984615 pixels
# Average reprojection error on image 12 is 0.11629470400595826 pixels
# Average reprojection error on image 24 is 0.10960784942066029 pixels
# Average reprojection error on image 11 is 0.20767117657967005 pixels
# Average reprojection error on image 25 is 0.11788231547446998 pixels
# Average reprojection error on image 10 is 0.2110122198603213 pixels
# Average reprojection error on image 26 is 0.11143712532723998 pixels
# Average reprojection error on image 9 is 0.1279008754362806 pixels
# Average reprojection error on image 27 is 0.1144361543029676 pixels
# Average reprojection error on image 8 is 0.12331654769775265 pixels
# Average reprojection error on image 28 is 0.12007006644036587 pixels
# Average reprojection error on image 7 is 0.12303037728898197 pixels
# Average reprojection error on image 29 is 0.12830463549803395 pixels
# Average reprojection error on image 6 is 0.1265142477304007 pixels
# Average reprojection error on image 30 is 0.16192110052891592 pixels
# Average reprojection error on image 5 is 0.11761835087071103 pixels
# Average reprojection error on image 31 is 0.23638397667349212 pixels
# Average reprojection error on image 4 is 0.11455969460230224 pixels
# Average reprojection error on image 32 is 0.22056421472993448 pixels
# Average reprojection error on image 3 is 0.11834438315966289 pixels
# Average reprojection error on image 33 is 0.15438634234746063 pixels
# Average reprojection error on image 2 is 0.10391694978217583 pixels
# Average reprojection error on image 34 is 0.18662006256514668 pixels
# Average reprojection error on image 1 is 0.12276524292736744 pixels
# Average reprojection error on image 35 is 3.486518212280777 pixels
# Average reprojection error across all 35 resected images is 0.23293619590509088 pixels
# Unresected image: 0, resected: 1
# rvec: [[-0.05810615]
#  [-2.62939493]
#  [-1.32866457]]
#
# tvec: [[ 0.85787306]
#  [-4.24487458]
#  [ 8.64393105]]
# Average error of reprojecting points used to resect image 0 back onto it is: 0.35226077810801676
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 233
# Triangulating: 278 points.
# Average reprojection error for just-triangulated points on image 0 is: 0.6206004212583024 pixels.
# Average reprojection error for just-triangulated points on image 1 is: 2.241505491817722 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.3762e+04                                    2.96e+06
#        1              2         1.6924e+03      1.21e+04       8.87e-01       1.18e+05
#        2              3         1.6742e+03      1.82e+01       3.37e-02       5.83e+03
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.3762e+04, final cost 1.6742e+03, first-order optimality 5.83e+03.
# Average reprojection error on image 17 is 0.1378247824880768 pixels
# Average reprojection error on image 18 is 0.11692057942824706 pixels
# Average reprojection error on image 19 is 0.14341039641618167 pixels
# Average reprojection error on image 16 is 0.1348519456393891 pixels
# Average reprojection error on image 20 is 0.15368149526743208 pixels
# Average reprojection error on image 15 is 0.1340064283823108 pixels
# Average reprojection error on image 21 is 0.11091283739576442 pixels
# Average reprojection error on image 14 is 0.12105214686477431 pixels
# Average reprojection error on image 22 is 0.11369035858367815 pixels
# Average reprojection error on image 13 is 0.11534131791525916 pixels
# Average reprojection error on image 23 is 0.10950088277529257 pixels
# Average reprojection error on image 12 is 0.11626186029408803 pixels
# Average reprojection error on image 24 is 0.10955125739447426 pixels
# Average reprojection error on image 11 is 0.20763389841626612 pixels
# Average reprojection error on image 25 is 0.11781059340915684 pixels
# Average reprojection error on image 10 is 0.21087113854519918 pixels
# Average reprojection error on image 26 is 0.11113614768966402 pixels
# Average reprojection error on image 9 is 0.12794317386176604 pixels
# Average reprojection error on image 27 is 0.11345165213687346 pixels
# Average reprojection error on image 8 is 0.12341244627365769 pixels
# Average reprojection error on image 28 is 0.11693158370367826 pixels
# Average reprojection error on image 7 is 0.1235193628736769 pixels
# Average reprojection error on image 29 is 0.1195670671080898 pixels
# Average reprojection error on image 6 is 0.12714155663133808 pixels
# Average reprojection error on image 30 is 0.14407777633703017 pixels
# Average reprojection error on image 5 is 0.11882223024304535 pixels
# Average reprojection error on image 31 is 0.2044769830155369 pixels
# Average reprojection error on image 4 is 0.11826557394908982 pixels
# Average reprojection error on image 32 is 0.2019570868632796 pixels
# Average reprojection error on image 3 is 0.12439720189538511 pixels
# Average reprojection error on image 33 is 0.15084217134264694 pixels
# Average reprojection error on image 2 is 0.11830067363470356 pixels
# Average reprojection error on image 34 is 0.12339075818303137 pixels
# Average reprojection error on image 1 is 0.10602256229684974 pixels
# Average reprojection error on image 35 is 0.11449261943791819 pixels
# Average reprojection error on image 0 is 0.11251814609842381 pixels
# Average reprojection error across all 36 resected images is 0.1320552414664243 pixels

# %%
import plotly.graph_objects as go

def plot_model(points3d_with_views):
    # Extract the 3D points from points3d_with_views
    pts_cloud = np.array([pt3.point3d[0] for pt3 in points3d_with_views if np.abs(pt3.point3d[0]).sum() < 200])

    # Assuming points_3D is your array of 3D points
    x = pts_cloud[:, 0]
    y = pts_cloud[:, 1]
    z = pts_cloud[:, 2]

    fig = go.Figure(data=[go.Scatter3d(
        x=x,
        y=y,
        z=z,
        mode='markers',
        marker=dict(
            size=2,
            color=z,                # set color to an array/list of desired values
            colorscale='Viridis',   # choose a colorscale
            opacity=0.8
        )
    )])

    # tight layout
    fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
    fig.show()
plot_model(points3d_with_views)
