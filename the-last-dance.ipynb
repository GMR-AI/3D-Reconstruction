# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import plotly.graph_objects as go
import cv2
import os
import pyntcloud
import pandas as pd
from scipy.optimize import least_squares
from scipy.sparse import lil_matrix

# %%
def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder, filename))
        if img is not None:
            images.append(img)
    return images

# %%
def feature_extraction_set(images):
    sift = cv2.SIFT_create()

    kp, des = [], []
    for im in images:
        kp_tmp, des_tmp = sift.detectAndCompute(im, None) # This assumes the extraction method to be from the CV2 library
        kp.append(kp_tmp)
        des.append(des_tmp)
    return kp, des # Can't turn them into a np array since their shape can be inhomogeneous

# %%
def feature_matching_set(kp, des):
    # Initialize FLANN matching
    FLANN_INDEX_KDTREE = 0
    index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
    search_params = dict(checks=50)
    flann = cv2.FlannBasedMatcher(index_params, search_params)

    matches = {} # Dict for easier access to each match
    for i in range(len(kp)):
        for j in range(i+1, len(kp)): # Only match each image with the rest, we don't need the full matrix
            matches_tmp = flann.knnMatch(des[i], des[j], k=2)

            # Lowe's ratio test
            good_matches = [m for m, n in matches_tmp if m.distance < 0.7 * n.distance]

            if len(good_matches) >= 4:
                # RANSAC to find homography and get inlier's mask
                pts1 = np.float32([kp[i][m.queryIdx].pt for m in good_matches]).reshape(-1, 1, 2)
                pts2 = np.float32([kp[j][m.trainIdx].pt for m in good_matches]).reshape(-1, 1, 2)
                _, mask = cv2.findHomography(pts1, pts2, cv2.RANSAC, 5.0)

                inliers = [good_matches[k] for k in range(len(good_matches)) if mask[k]==1]
                matches[(i,j)] = inliers
            else:
                matches[(i,j)] = []
    
    return matches

# %%
def find_matches(matcher, keypoints, descriptors, lowes_ratio=0.7):
    matches = []
    n_imgs = len(keypoints)
    for i in range(n_imgs):
        matches.append([])
        for j in range(n_imgs):
            if j <= i: matches[i].append(None)
            else:
                match = []
                m = matcher.knnMatch(descriptors[i], descriptors[j], k=2)
                for k in range(len(m)):
                    try:
                        if m[k][0].distance < lowes_ratio*m[k][1].distance:
                            match.append(m[k][0])
                    except:
                        continue
                matches[i].append(match)
    return matches


def remove_outliers(matches, keypoints):
    for i in range(len(matches)):
        for j in range(len(matches[i])):
            if j <= i: continue
            if len(matches[i][j]) < 20:
                matches[i][j] = []
                continue
            kpts_i = []
            kpts_j = []
            for k in range(len(matches[i][j])):
                kpts_i.append(keypoints[i][matches[i][j][k].queryIdx].pt)
                kpts_j.append(keypoints[j][matches[i][j][k].trainIdx].pt)
            kpts_i = np.int32(kpts_i)
            kpts_j = np.int32(kpts_j)
            F, mask = cv2.findFundamentalMat(kpts_i, kpts_j, cv2.FM_RANSAC, ransacReprojThreshold=3)
            if np.linalg.det(F) > 1e-7: raise ValueError(f"Bad F_mat between images: {i}, {j}. Determinant: {np.linalg.det(F)}")
            matches[i][j] = np.array(matches[i][j])
            if mask is None:
                matches[i][j] = []
                continue
            matches[i][j] = matches[i][j][mask.ravel() == 1]
            matches[i][j] = list(matches[i][j])

            if len(matches[i][j]) < 20:
                matches[i][j] = []
                continue

    return matches

# %%
def adjacency_matrix(num_imgs, matches):
    num_img_pairs = 0
    num_pairs = 0
    pairs = []
    img_adjacency = np.zeros((num_imgs, num_imgs))
    for i in range(len(matches)):
        for j in range(len(matches[i])):
            if j <= i: continue
            num_pairs += 1
            if len(matches[i][j]) > 0:
                num_img_pairs += 1
                pairs.append((i,j))
                img_adjacency[i][j] = 1

    list_of_img_pairs = pairs
    return img_adjacency, list_of_img_pairs

# %%
import numpy as np
import random
import cv2

class Point3D_with_views:
    def __init__(self, point3d, source_2dpt_idxs):
        self.point3d = point3d
        self.source_2dpt_idxs = source_2dpt_idxs

def best_img_pair(img_adjacency, matches, keypoints, K, top_x_perc=0.2):
    num_matches = []

    for i in range(img_adjacency.shape[0]):
        for j in range(img_adjacency.shape[1]):
            if img_adjacency[i][j] == 1:
                num_matches.append(len(matches[i][j]))

    num_matches = sorted(num_matches, reverse=True)
    min_match_idx = int(len(num_matches)*top_x_perc)
    min_matches = num_matches[min_match_idx]
    best_R = 0
    best_pair = None

    for i in range(img_adjacency.shape[0]):
        for j in range(img_adjacency.shape[1]):
            if img_adjacency[i][j] == 1:
                if len(matches[i][j]) > min_matches:
                    kpts_i, kpts_j, _, _ = get_aligned_kpts(i, j, keypoints, matches)
                    E, _ = cv2.findEssentialMat(kpts_i, kpts_j, K, cv2.FM_RANSAC, 0.999, 1.0)
                    points, R1, _, _ = cv2.recoverPose(E, kpts_i, kpts_j, K)
                    rvec, _ = cv2.Rodrigues(R1)
                    rot_angle = abs(rvec[0]) +abs(rvec[1]) + abs(rvec[2])# sum rotation angles for each dimension
                    if (rot_angle > best_R or best_pair == None) and points == len(kpts_i): #Ensure recoverPose worked.
                        best_R = rot_angle
                        best_pair = (i,j)
    return best_pair

def get_aligned_kpts(i, j, keypoints, matches, mask=None):
    if mask is None:
        mask = np.ones(len(matches[i][j])) #if no mask is given, all matches used. This is helpful if we only want to triangulate certain matches.

    kpts_i, kpts_i_idxs, kpts_j, kpts_j_idxs = [], [], [], []
    for k in range(len(matches[i][j])):
        if mask[k] == 0: continue
        kpts_i.append(keypoints[i][matches[i][j][k].queryIdx].pt)
        kpts_i_idxs.append(matches[i][j][k].queryIdx)
        kpts_j.append(keypoints[j][matches[i][j][k].trainIdx].pt)
        kpts_j_idxs.append(matches[i][j][k].trainIdx)
    kpts_i = np.array(kpts_i)
    kpts_j = np.array(kpts_j)
    kpts_i = np.expand_dims(kpts_i, axis=1) #this seems to be required for cv2.undistortPoints and cv2.trangulatePoints to work
    kpts_j = np.expand_dims(kpts_j, axis=1)

    return kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs

def triangulate_points_and_reproject(R_l, t_l, R_r, t_r, K, points3d_with_views, img_idx1, img_idx2, kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs, reproject=True):
    print(f"Triangulating: {len(kpts_i)} points.")
    P_l = np.dot(K, np.hstack((R_l, t_l)))
    P_r = np.dot(K, np.hstack((R_r, t_r)))

    kpts_i = np.squeeze(kpts_i)
    kpts_i = kpts_i.transpose()
    kpts_i = kpts_i.reshape(2,-1)
    kpts_j = np.squeeze(kpts_j)
    kpts_j = kpts_j.transpose()
    kpts_j = kpts_j.reshape(2,-1)

    point_4d_hom = cv2.triangulatePoints(P_l, P_r, kpts_i, kpts_j)
    points_3D = cv2.convertPointsFromHomogeneous(point_4d_hom.transpose())
    for i in range(kpts_i.shape[1]):
        source_2dpt_idxs = {img_idx1:kpts_i_idxs[i], img_idx2:kpts_j_idxs[i]}
        pt = Point3D_with_views(points_3D[i], source_2dpt_idxs)
        points3d_with_views.append(pt)

    if reproject:
        kpts_i = kpts_i.transpose()
        kpts_j = kpts_j.transpose()
        rvec_l, _ = cv2.Rodrigues(R_l)
        rvec_r, _ = cv2.Rodrigues(R_r)
        projPoints_l, _ = cv2.projectPoints(points_3D, rvec_l, t_l, K, distCoeffs=np.array([]))
        projPoints_r, _ = cv2.projectPoints(points_3D, rvec_r, t_r, K, distCoeffs=np.array([]))
        delta_l , delta_r = [], []
        for i in range(len(projPoints_l)):
            delta_l.append(abs(projPoints_l[i][0][0] - kpts_i[i][0]))
            delta_l.append(abs(projPoints_l[i][0][1] - kpts_i[i][1]))
            delta_r.append(abs(projPoints_r[i][0][0] - kpts_j[i][0]))
            delta_r.append(abs(projPoints_r[i][0][1] - kpts_j[i][1]))
        avg_error_l = sum(delta_l)/len(delta_l)
        avg_error_r = sum(delta_r)/len(delta_r)
        errors = list(zip(delta_l, delta_r))
        return points3d_with_views, errors, avg_error_l, avg_error_r

    return points3d_with_views

def initialize_reconstruction(keypoints, matches, K, img_idx1, img_idx2):
    kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs = get_aligned_kpts(img_idx1, img_idx2, keypoints, matches)
    E, _ = cv2.findEssentialMat(kpts_i, kpts_j, K, cv2.FM_RANSAC, 0.999, 1.0)
    points, R1, t1, mask = cv2.recoverPose(E, kpts_i, kpts_j, K)
    assert abs(np.linalg.det(R1)) - 1 < 1e-7

    R0 = np.eye(3, 3)
    t0 = np.zeros((3, 1))

    points3d_with_views = []
    points3d_with_views = triangulate_points_and_reproject(
        R0, t0, R1, t1, K, points3d_with_views, img_idx1, img_idx2, kpts_i, kpts_j, kpts_i_idxs, kpts_j_idxs, reproject=False)

    return R0, t0, R1, t1, points3d_with_views

def get_idxs_in_correct_order(idx1, idx2):
    if idx1 < idx2: return idx1, idx2
    else: return idx2, idx1

def next_img_pair_to_grow_reconstruction(n_imgs, init_pair, resected_imgs, unresected_imgs, img_adjacency):
    if len(unresected_imgs) == 0: raise ValueError('Should not check next image to resect if all have been resected already!')
    straddle = False
    if init_pair[1] - init_pair[0] > n_imgs/2 : straddle = True #initial pair straddles "end" of the circle (ie if init pair is idxs (0, 49) for 50 images)

    init_arc = init_pair[1] - init_pair[0] + 1 # Number of images between and including initial pair

    #fill in images between initial pair
    if len(resected_imgs) < init_arc:
        if straddle == False: idx = resected_imgs[-2] + 1
        else: idx = resected_imgs[-1] + 1
        while True:
            if idx not in resected_imgs:
                prepend = True
                unresected_idx = idx
                resected_idx = random.choice(resected_imgs)
                return resected_idx, unresected_idx, prepend
            idx = idx + 1 % n_imgs

    extensions = len(resected_imgs) - init_arc # How many images have been resected after the initial arc
    if straddle == True: #smaller init_idx should be increased and larger decreased
        if extensions % 2 == 0:
            unresected_idx = (init_pair[0] + int(extensions/2) + 1) % n_imgs
            resected_idx = (unresected_idx - 1) % n_imgs
        else:
            unresected_idx = (init_pair[1] - int(extensions/2) - 1) % n_imgs
            resected_idx = (unresected_idx + 1) % n_imgs
    else:
        if extensions % 2 == 0:
            unresected_idx = (init_pair[1] + int(extensions/2) + 1) % n_imgs
            resected_idx = (unresected_idx - 1) % n_imgs
        else:
            unresected_idx = (init_pair[0] - int(extensions/2) - 1) % n_imgs
            resected_idx = (unresected_idx + 1) % n_imgs

    prepend = False
    return resected_idx, unresected_idx, prepend

def check_and_get_unresected_point(resected_kpt_idx, match, resected_idx, unresected_idx):
    if resected_idx < unresected_idx:
        if resected_kpt_idx == match.queryIdx:
            unresected_kpt_idx = match.trainIdx
            success = True
            return unresected_kpt_idx, success
        else:
            return None, False
    elif unresected_idx < resected_idx:
        if resected_kpt_idx == match.trainIdx:
            unresected_kpt_idx = match.queryIdx
            success = True
            return unresected_kpt_idx, success
        else:
            return None, False

def get_correspondences_for_pnp(resected_idx, unresected_idx, pts3d, matches, keypoints):
    idx1, idx2 = get_idxs_in_correct_order(resected_idx, unresected_idx)
    triangulation_status = np.ones(len(matches[idx1][idx2])) # if triangulation_status[x] = 1, then matches[x] used for triangulation
    pts3d_for_pnp = []
    pts2d_for_pnp = []
    for pt3d in pts3d:
        if resected_idx not in pt3d.source_2dpt_idxs: continue
        resected_kpt_idx = pt3d.source_2dpt_idxs[resected_idx]
        for k in range(len(matches[idx1][idx2])):
            unresected_kpt_idx, success = check_and_get_unresected_point(resected_kpt_idx, matches[idx1][idx2][k], resected_idx, unresected_idx)
            if not success: continue
            pt3d.source_2dpt_idxs[unresected_idx] = unresected_kpt_idx #Add new 2d/3d correspondences to 3D point object
            pts3d_for_pnp.append(pt3d.point3d)
            pts2d_for_pnp.append(keypoints[unresected_idx][unresected_kpt_idx].pt)
            triangulation_status[k] = 0

    return pts3d, pts3d_for_pnp, pts2d_for_pnp, triangulation_status

def do_pnp(pts3d_for_pnp, pts2d_for_pnp, K, iterations=200, reprojThresh=5):
    list_pts3d_for_pnp = pts3d_for_pnp
    list_pts2d_for_pnp = pts2d_for_pnp
    pts3d_for_pnp = np.squeeze(np.array(pts3d_for_pnp))
    pts2d_for_pnp = np.expand_dims(np.squeeze(np.array(pts2d_for_pnp)), axis=1)
    num_pts = len(pts3d_for_pnp)

    highest_inliers = 0
    for i in range(iterations):
        pt_idxs = np.random.choice(num_pts, 6, replace=False)
        pts3 = np.array([pts3d_for_pnp[pt_idxs[i]] for i in range(len(pt_idxs))])
        pts2 = np.array([pts2d_for_pnp[pt_idxs[i]] for i in range(len(pt_idxs))])
        _, rvec, tvec = cv2.solvePnP(pts3, pts2, K, distCoeffs=np.array([]), flags=cv2.SOLVEPNP_ITERATIVE)
        R, _ = cv2.Rodrigues(rvec)
        _, _, _, perc_inliers = test_reproj_pnp_points(list_pts3d_for_pnp, list_pts2d_for_pnp, R, tvec, K, rep_thresh=reprojThresh)
        if highest_inliers < perc_inliers:
            highest_inliers = perc_inliers
            best_R = R
            best_tvec = tvec
    R = best_R
    tvec = best_tvec
    print('rvec:', rvec,'\n\ntvec:', tvec)

    return R, tvec

def prep_for_reproj(img_idx, points3d_with_views, keypoints):
    points_3d = []
    points_2d = []
    pt3d_idxs = []
    i = 0
    for pt3d in points3d_with_views:
        if img_idx in pt3d.source_2dpt_idxs.keys():
            pt3d_idxs.append(i)
            points_3d.append(pt3d.point3d)
            kpt_idx = pt3d.source_2dpt_idxs[img_idx]
            points_2d.append(keypoints[img_idx][kpt_idx].pt)
        i += 1

    return np.array(points_3d), np.array(points_2d), pt3d_idxs

def calculate_reproj_errors(projPoints, points_2d):
    assert len(projPoints) == len(points_2d)
    delta = []
    for i in range(len(projPoints)):
        delta.append(abs(projPoints[i] - points_2d[i]))

    average_delta = sum(delta)/len(delta) # 2-vector, average error for x and y coord
    average_delta = (average_delta[0] + average_delta[1])/2 # average error overall

    return average_delta, delta

def get_reproj_errors(img_idx, points3d_with_views, R, t, K, keypoints, distCoeffs=np.array([])):
    points_3d, points_2d, pt3d_idxs = prep_for_reproj(img_idx, points3d_with_views, keypoints)
    rvec, _ = cv2.Rodrigues(R)
    projPoints, _ = cv2.projectPoints(points_3d, rvec, t, K, distCoeffs=distCoeffs)
    projPoints = np.squeeze(projPoints)
    avg_error, errors = calculate_reproj_errors(projPoints, points_2d)

    return points_3d, points_2d, avg_error, errors

def test_reproj_pnp_points(pts3d_for_pnp, pts2d_for_pnp, R_new, t_new, K, rep_thresh=5):
    errors = []
    projpts = []
    inliers = []
    for i in range(len(pts3d_for_pnp)):
        Xw = pts3d_for_pnp[i][0]
        Xr = np.dot(R_new, Xw).reshape(3,1)
        Xc = Xr + t_new
        x = np.dot(K, Xc)
        x /= x[2]
        errors.append([np.float64(x[0] - pts2d_for_pnp[i][0]), np.float64(x[1] - pts2d_for_pnp[i][1])])
        projpts.append(x)
        if abs(errors[-1][0]) > rep_thresh or abs(errors[-1][1]) > rep_thresh: inliers.append(0)
        else: inliers.append(1)
    a = 0
    for e in errors:
        a = a + abs(e[0]) + abs(e[1])
    avg_err = a/(2*len(errors))
    perc_inliers = sum(inliers)/len(inliers)

    return errors, projpts, avg_err, perc_inliers

# %%
def bundle_adjustment_sparsity(n_cameras, n_points, camera_indices, point_indices):
    m = camera_indices.size * 2
    n = n_cameras * 12 + n_points * 3
    A = lil_matrix((m, n), dtype=int)

    i = np.arange(camera_indices.size)
    for s in range(12):
        A[2 * i, camera_indices * 12 + s] = 1
        A[2 * i + 1, camera_indices * 12 + s] = 1

    for s in range(3):
        A[2 * i, n_cameras * 12 + point_indices * 3 + s] = 1
        A[2 * i + 1, n_cameras * 12 + point_indices * 3 + s] = 1

    return A

def project(points, camera_params, K):
    points_proj = []

    for idx in range(len(camera_params)): # idx applies to both points and cam_params, they are = length vectors
        R = camera_params[idx][:9].reshape(3,3)
        rvec, _ = cv2.Rodrigues(R)
        t = camera_params[idx][9:]
        pt = points[idx]
        pt = np.expand_dims(pt, axis=0)
        pt, _ = cv2.projectPoints(pt, rvec, t, K, distCoeffs=np.array([]))
        pt = np.squeeze(np.array(pt))
        points_proj.append(pt)

    return points_proj

def fun(params, n_cameras, n_points, camera_indices, point_indices, points_2d, K):
    camera_params = params[:n_cameras * 12].reshape((n_cameras, 12))
    points_3d = params[n_cameras * 12:].reshape((n_points, 3))
    points_proj = project(points_3d[point_indices], camera_params[camera_indices], K)
    return (points_proj - points_2d).ravel()

def do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, keypoints, K, ftol):
    point_indices = []
    points_2d = []
    camera_indices = []
    points_3d = []
    camera_params = []
    BA_cam_idxs = {} # maps from true cam indices to 'normalized' (i.e 11, 23, 31 maps to -> 0, 1, 2)
    cam_count = 0

    for r in resected_imgs:
        BA_cam_idxs[r] = cam_count
        camera_params.append(np.hstack((R_mats[r].ravel(), t_vecs[r].ravel())))
        cam_count += 1

    for pt3d_idx in range(len(points3d_with_views)):
        points_3d.append(points3d_with_views[pt3d_idx].point3d)
        for cam_idx, kpt_idx in points3d_with_views[pt3d_idx].source_2dpt_idxs.items():
            if cam_idx not in resected_imgs: continue
            point_indices.append(pt3d_idx)
            camera_indices.append(BA_cam_idxs[cam_idx])#append normalized cam idx
            points_2d.append(keypoints[cam_idx][kpt_idx].pt)
    if len(points_3d[0]) == 3: points_3d = np.expand_dims(points_3d, axis=0)

    point_indices = np.array(point_indices)
    points_2d = np.array(points_2d)
    camera_indices = np.array(camera_indices)
    points_3d = np.squeeze(points_3d)
    camera_params = np.array(camera_params)

    n_cameras = camera_params.shape[0]
    n_points = points_3d.shape[0]
    x0 = np.hstack((camera_params.ravel(), points_3d.ravel()))
    A = bundle_adjustment_sparsity(n_cameras, n_points, camera_indices, point_indices)

    res = least_squares(fun, x0, jac_sparsity=A, verbose=2, x_scale='jac', loss='linear', ftol=ftol, xtol=1e-12, method='trf',
                        args=(n_cameras, n_points, camera_indices, point_indices, points_2d, K))

    adjusted_camera_params = res.x[:n_cameras * 12].reshape(n_cameras, 12)
    adjusted_points_3d = res.x[n_cameras * 12:].reshape(n_points, 3)
    adjusted_R_mats = {}
    adjusted_t_vecs = {}
    for true_idx, norm_idx in BA_cam_idxs.items():
        adjusted_R_mats[true_idx] = adjusted_camera_params[norm_idx][:9].reshape(3,3)
        adjusted_t_vecs[true_idx] = adjusted_camera_params[norm_idx][9:].reshape(3,1)
    R_mats = adjusted_R_mats
    t_vecs = adjusted_t_vecs
    for pt3d_idx in range(len(points3d_with_views)):
        points3d_with_views[pt3d_idx].point3d = np.expand_dims(adjusted_points_3d[pt3d_idx], axis=0)

    return points3d_with_views, R_mats, t_vecs

# %%
def normalize(pts):
    x_mean = np.mean(pts[:, 0])
    y_mean = np.mean(pts[:, 1])
    sigma = np.mean(np.sqrt((pts[:, 0] - x_mean) ** 2 + (pts[:, 1] - y_mean) ** 2))
    M = np.sqrt(2) / sigma
    T = np.array([
        [M, 0, -M * x_mean],
        [0, M, -M * y_mean],
        [0, 0, 1]
    ])
    return T

def eight_point_algorithm(pts1, pts2):

    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1]))).T
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1]))).T

    # Normalization
    T = normalize(pts1_homo)
    T_prime = normalize(pts2_homo)


    pts1_homo = (T @ pts1_homo.T).T
    pts2_homo = (T_prime @ pts2_homo.T).T

    # x2.T*F*x1=0
    # A*f=0, f is F flattened into a 1D array
    

    # Create A
    A = np.zeros((pts1.shape[1], 9))
    for i in range(pts1.shape[1]):
        A[i] = np.array([
            pts1_homo[i,0]*pts2_homo[i,0], pts1_homo[i,1]*pts2_homo[i,0], pts1_homo[i,2]*pts2_homo[i,0],
            pts1_homo[i,0]*pts2_homo[i,1], pts1_homo[i,1]*pts2_homo[i,1], pts1_homo[i,2]*pts2_homo[i,1],
            pts1_homo[i,0]*pts2_homo[i,2], pts1_homo[i,1]*pts2_homo[i,2], pts1_homo[i,2]*pts2_homo[i,2]
            ])
    
    # Solve Af=0 using svd
    U,S,Vt = np.linalg.svd(A)
    F = Vt[-1,:].reshape((3,3))

    # Enforce rank2 constraint
    U,S,Vt = np.linalg.svd(F)
    S[-1] = 0
    F = U @ np.diag(S) @ Vt

    F = T_prime.T @ F @ T
    return F

# %%
def essential_from_fundamental(K1, F, K2):
    return K1.T @ F @ K2

# %%
def pose_from_essential(E):
    U,_,Vt = np.linalg.svd(E)
    W = np.array([[0, -1, 0], [1, 0, 0], [0, 0, 1]])
    
    Rs = [U @ W @ Vt, U @ W.T @ Vt]
    for i in range(len(Rs)):
        if np.linalg.det(Rs[i]) < 0:
            Rs[i] = Rs[i] * -1

    # Array with all possible camera poses (extrinsics)
    RTs = np.array([
        np.hstack((Rs[0], U[:, 2, np.newaxis])),
        np.hstack((Rs[0], -U[:, 2, np.newaxis])),
        np.hstack((Rs[1], U[:, 2, np.newaxis])),
        np.hstack((Rs[1], -U[:, 2, np.newaxis])),
    ])

    return RTs

# %%
def linear_triangulation(K1, RT1, K2, RT2, pts1, pts2):
    # First, set all points to homogeneous
    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1])))
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1])))

    # Calculate every projection matrix
    P1 = K1 @ RT1
    P2 = K2 @ RT2

    # Solve using svd
    pts3d = np.zeros((3, pts1.shape[1]))
    for i in range(pts1.shape[1]):
        A = np.array([pts1_homo[1,i]*P1[2,:] - P1[1,:],
            P1[0,:] - pts1_homo[0,i]*P1[2,:],
            pts2_homo[1,i]*P2[2,:] - P2[1,:],
            P2[0,:] - pts2_homo[0,i]*P2[2,:]])
        ATA = A.T @ A
        _, _, Vt = np.linalg.svd(ATA)
        pts3d[:, i] = Vt[-1, :3]/Vt[-1, -1]
    
    return pts3d

def linear_triangulation2(P1, P2, pts1, pts2):
    # First, set all points to homogeneous
    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1])))
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1])))

    # Solve using svd
    pts3d = np.zeros((3, pts1.shape[1]))
    for i in range(pts1.shape[1]):
        A = np.array([pts1_homo[1,i]*P1[2,:] - P1[1,:],
                      P1[0,:] - pts1_homo[0,i]*P1[2,:],
                      pts2_homo[1,i]*P2[2,:] - P2[1,:],
                      P2[0,:] - pts2_homo[0,i]*P2[2,:]])
        ATA = A.T @ A
        _, _, Vt = np.linalg.svd(ATA)
        pts3d[:, i] = Vt[-1, :3]/Vt[-1, -1]
    
    return pts3d

# %%
def reprojection(P1, P2, pts3d):
    pts3d_homo = np.vstack((pts3d, np.ones(pts3d.shape[1])))
    pts2d1_homo = np.dot(P1, pts3d_homo)
    pts2d2_homo = np.dot(P2, pts3d_homo)
    return pts2d1_homo/pts2d1_homo[-1], pts2d2_homo/pts2d2_homo[-1]

def double_disambiguation(K1, RT1, K2, RT2s, pts1, pts2, pts3d):
    max_positive_z = 0
    min_error = np.finfo('float').max
    best_RT = None
    best_pts3d = None
    P1 = K1 @ RT1

    pts1_homo = np.vstack((pts1, np.ones(pts1.shape[1])))
    pts2_homo = np.vstack((pts2, np.ones(pts2.shape[1])))

    for i in range(RT2s.shape[0]):
        P2 = K2 @ RT2s[i]
        num_positive_z = np.sum(pts3d[i][2, :] > 0)
        re1_pts2, re2_pts2 = reprojection(P1, P2, pts3d[i])

        err1 = np.sum(np.square(re1_pts2 - pts1_homo))
        err2 = np.sum(np.square(re2_pts2 - pts2_homo))

        err = err1 + err2

        if num_positive_z >= max_positive_z and err < min_error:
            max_positive_z = num_positive_z
            min_error = err
            best_RT = RT2s[i]
            best_pts3d = pts3d[i]
    
    return best_RT, best_pts3d

# %%
def calculate_projection_matrix(K, pts3d, pts2d):
    _, rod, T, _ = cv2.solvePnPRansac(pts3d.T, pts2d.T, K, None)#, flags=cv2.SOLVEPNP_P3P)
    R = cv2.Rodrigues(rod)[0]
    if np.linalg.det(R) < 0:
        R = R * -1
    P = K @ np.hstack((R, T))
    return P

# %%
def plot_model(pts_cloud):
    # Assuming points_3D is your array of 3D points
    x = pts_cloud[0]
    y = pts_cloud[1]
    z = pts_cloud[2]

    fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z,
                                    mode='markers',
                                    marker=dict(size=2, color=z, colorscale='Viridis'))])

    fig.update_layout(scene=dict(xaxis_title='X',
                                yaxis_title='Y',
                                zaxis_title='Z'))

    fig.show()

# %%
def two_images_sfm(im1, im2, K):
    # Feature extraction
    kp, des = feature_extraction_set([im1, im2])

    # Feature matching
    matches = feature_matching_set(kp, des)

    # Fundamental matrix
    pts1 = np.transpose([kp[0][m.queryIdx].pt for m in matches[(0,1)]])
    pts2 = np.transpose([kp[1][m.trainIdx].pt for m in matches[(0,1)]])

    F = eight_point_algorithm(pts1, pts2)

    # Essential matrix
    E = essential_from_fundamental(K, F, K) # In this case, the same intrinsic values apply to all images

    # Get camera extrinsics from Essential matrix
    RT2s = pose_from_essential(E)

    # Define RT for camera 1 (center at world origin and matching orientation)
    RT1 = np.hstack((np.eye(3), np.zeros((3, 1))))
    
    RT2 = RT2s[0]

    pts3d = np.array([linear_triangulation(K, RT1, K, RT2, pts1, pts2) for RT2 in RT2s])

    RT2, pts_cloud = double_disambiguation(K, RT1, K, RT2s, pts1, pts2, pts3d)

    plot_model(pts_cloud)

    # Initialize general Projection matrix list, RTs list and 3d points list

    return K @ RT1, K @ RT2, pts_cloud

# %%
# Load all images
images = np.array(load_images_from_folder('dinos'))[:-1]

# %%
# K = np.loadtxt('intrinsic_matrix.txt', dtype=float)

height, width = images.shape[1:3]
K = np.array([  # for dino
    [2360, 0, width / 2],
    [0, 2360, height / 2],
    [0, 0, 1]])

# %%
kp, des = feature_extraction_set(images)
matches = feature_matching_set(kp, des)

# %%
image_count = 0
pts_cloud = []
P_list = []

while image_count < images.shape[0]:
    P1, P2, pts3d = two_images_sfm(images[image_count], images[image_count+1], K)
    pts_cloud.append(pts3d)
    image_count += 2
    P_list.append([P1, P2])

    for i in range(image_count, images.shape[0]):
        idx1, idx2, idx3 = i-2, i-1, i
        image_count += 1
        
        # Get Common matches of 3 images
        common_matches1 = [m1 for m1 in matches[(idx1, idx3)] for m2 in matches[(idx2, idx3)] if m1.trainIdx == m2.trainIdx]
        common_matches2 = [m2 for m1 in matches[(idx1, idx3)] for m2 in matches[(idx2, idx3)] if m1.trainIdx == m2.trainIdx]
        
        if len(common_matches1) < 4:
            print('STOP')
            break

        # Triangulate common points
        common_pts1 = np.transpose([kp[idx1][m.queryIdx].pt for m in common_matches1])
        common_pts2 = np.transpose([kp[idx2][m.queryIdx].pt for m in common_matches2])
        common_pts3 = np.transpose([kp[idx3][m.trainIdx].pt for m in common_matches1])

        common_pts3d = linear_triangulation2(P_list[-1][-2], P_list[-1][-1], common_pts1, common_pts2)

        # Get Projection matrix
        P = calculate_projection_matrix(K, common_pts3d, common_pts3)

        P_list[-1].append(P)
        
        # Triangulate
        pts1_list = [np.transpose([kp[j][m.queryIdx].pt for m in matches[(j,idx3)]]) for j in range(idx1, idx3)]
        pts2_list = [np.transpose([kp[idx3][m.trainIdx].pt for m in matches[(j,idx3)]]) for j in range(idx1, idx3)]

        for j in range(2):
            pts3d = linear_triangulation2(P_list[-1][-3+j], P_list[-1][-1], pts1_list[j], pts2_list[j])
            pts_cloud[-1] = np.hstack((pts_cloud[-1], pts3d))
# Out:
# STOP

# %%
for pts in pts_cloud:
    plot_model(pts)

# %%
# Load all images
images = np.array(load_images_from_folder('dinos'))[:-1]
height, width = images.shape[1:3]
K = np.array([  # for dino
    [2360, 0, width / 2],
    [0, 2360, height / 2],
    [0, 0, 1]])

kp, des = feature_extraction_set(images)
matcher = cv2.BFMatcher(cv2.NORM_L1)
matches = find_matches(matcher, kp, des)
matches = remove_outliers(matches, kp)
img_adjacency, list_of_img_pairs = create_img_adjacency_matrix(len(images), matches)

# %%
best_pair = best_img_pair(img_adjacency, matches, kp, K, top_x_perc=0.2)
R0, t0, R1, t1, points3d_with_views = initialize_reconstruction(kp, matches, K, best_pair[0], best_pair[1])

R_mats = {best_pair[0]: R0, best_pair[1]: R1}
t_vecs = {best_pair[0]: t0, best_pair[1]: t1}

resected_imgs = [best_pair[0], best_pair[1]] 
unresected_imgs = [i for i in range(len(images)) if i not in resected_imgs] 
avg_err = 0
# Out:
# Triangulating: 453 points.

# %%
### This cell grows and refines the reconstruction 
BA_chkpts = [3,4,5,6] + [int(6*(1.34**i)) for i in range(25)]
while len(unresected_imgs) > 0:
    resected_idx, unresected_idx, prepend = next_img_pair_to_grow_reconstruction(len(images), best_pair, resected_imgs, unresected_imgs, img_adjacency)
    points3d_with_views, pts3d_for_pnp, pts2d_for_pnp, triangulation_status = get_correspondences_for_pnp(resected_idx, unresected_idx, points3d_with_views, matches, kp)
    if len(pts3d_for_pnp) < 12:
        print(f"{len(pts3d_for_pnp)} is too few correspondences for pnp. Skipping imgs resected:{resected_idx} and unresected:{unresected_idx}")
        print(f"Currently resected imgs: {resected_imgs}, unresected: {unresected_imgs}")
        continue

    R_res = R_mats[resected_idx]
    t_res = t_vecs[resected_idx]
    print(f"Unresected image: {unresected_idx}, resected: {resected_idx}")
    R_new, t_new = do_pnp(pts3d_for_pnp, pts2d_for_pnp, K)
    R_mats[unresected_idx] = R_new
    t_vecs[unresected_idx] = t_new
    if prepend == True: resected_imgs.insert(0, unresected_idx)
    else: resected_imgs.append(unresected_idx)
    unresected_imgs.remove(unresected_idx)
    pnp_errors, projpts, avg_err, perc_inliers = test_reproj_pnp_points(pts3d_for_pnp, pts2d_for_pnp, R_new, t_new, K)
    print(f"Average error of reprojecting points used to resect image {unresected_idx} back onto it is: {avg_err}")
    print(f"Fraction of Pnp inliers: {perc_inliers} num pts used in Pnp: {len(pnp_errors)}")
    
    if resected_idx < unresected_idx:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = get_aligned_kpts(resected_idx, unresected_idx, kp, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = triangulate_points_and_reproject(R_res, t_res, R_new, t_new, K, points3d_with_views, resected_idx, unresected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    else:
        kpts1, kpts2, kpts1_idxs, kpts2_idxs = get_aligned_kpts(unresected_idx, resected_idx, kp, matches, mask=triangulation_status)
        if np.sum(triangulation_status) > 0: #at least 1 point needs to be triangulated
            points3d_with_views, tri_errors, avg_tri_err_l, avg_tri_err_r = triangulate_points_and_reproject(R_new, t_new, R_res, t_res, K, points3d_with_views, unresected_idx, resected_idx, kpts1, kpts2, kpts1_idxs, kpts2_idxs, reproject=True)
    if 0.8 < perc_inliers < 0.95 or 5 < avg_tri_err_l < 10 or 5 < avg_tri_err_r < 10: 
        #If % of inlers from Pnp is too low or triangulation error on either image is too high, bundle adjust
        points3d_with_views, R_mats, t_vecs = do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, kp, K, ftol=1e0)
        
    if len(resected_imgs) in BA_chkpts or len(unresected_imgs) == 0 or perc_inliers <= 0.8 or avg_tri_err_l >= 10 or avg_tri_err_r >= 10:
        #If % of inlers from Pnp is very low or triangulation error on either image is very high, bundle adjust with stricter tolerance
        points3d_with_views, R_mats, t_vecs = do_BA(points3d_with_views, R_mats, t_vecs, resected_imgs, kp, K, ftol=1e-1)
    
    av = 0
    for im in resected_imgs:
        p3d, p2d, avg_error, errors = get_reproj_errors(im, points3d_with_views, R_mats[im], t_vecs[im], K, kp, distCoeffs=np.array([]))
        print(f'Average reprojection error on image {im} is {avg_error} pixels')
        av += avg_error
    av = av/len(resected_imgs)
    print(f'Average reprojection error across all {len(resected_imgs)} resected images is {av} pixels')
# Out:
# Unresected image: 28, resected: 27
# rvec: [[-70.93074461]
#  [ 29.52146087]
#  [-87.26459294]]
#
# tvec: [[-1.56303514]
#  [-0.06422056]
#  [ 0.44759153]]
# Average error of reprojecting points used to resect image 28 back onto it is: 1.0923338695900682
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 175
# Triangulating: 157 points.
# Average reprojection error for just-triangulated points on image 27 is: 0.1747849541501749 pixels.
# Average reprojection error for just-triangulated points on image 28 is: 0.16497836917669037 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         4.3584e+02                                    1.36e+05
#        1              4         2.6538e+02      1.70e+02       8.37e-01       1.34e+05
#        2              6         1.5715e+02      1.08e+02       9.19e-02       5.03e+04
#        3              7         1.0911e+02      4.80e+01       9.93e-02       7.89e+04
#        4              8         1.0389e+02      5.21e+00       1.93e-01       8.14e+04
# `ftol` termination condition is satisfied.
# Function evaluations 8, initial cost 4.3584e+02, final cost 1.0389e+02, first-order optimality 8.14e+04.
# Average reprojection error on image 26 is 0.14048509962843964 pixels
# Average reprojection error on image 27 is 0.1620111966436361 pixels
# Average reprojection error on image 28 is 0.18083760428355888 pixels
# Average reprojection error across all 3 resected images is 0.16111130018521155 pixels
# Unresected image: 25, resected: 26
# rvec: [[ 0.19683014]
#  [-0.21907794]
#  [-0.07877511]]
#
# tvec: [[-0.87567021]
#  [-0.55634046]
#  [-5.44227857]]
# Average error of reprojecting points used to resect image 25 back onto it is: 1.747380762837872
# Fraction of Pnp inliers: 0.9333333333333333 num pts used in Pnp: 255
# Triangulating: 335 points.
# Average reprojection error for just-triangulated points on image 25 is: 0.6166381660335055 pixels.
# Average reprojection error for just-triangulated points on image 26 is: 0.5899358757790113 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.0089e+03                                    3.73e+05
#        1              4         1.5855e+03      4.23e+02       2.66e-01       3.78e+05
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 2.0089e+03, final cost 1.5855e+03, first-order optimality 3.78e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5855e+03                                    3.78e+05
#        1              4         1.3211e+03      2.64e+02       2.64e-01       2.72e+05
#        2              5         1.0748e+03      2.46e+02       2.90e-01       2.15e+05
#        3              6         1.0170e+03      5.77e+01       3.14e-01       3.15e+05
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.5855e+03, final cost 1.0170e+03, first-order optimality 3.15e+05.
# Average reprojection error on image 26 is 0.43114113704346 pixels
# Average reprojection error on image 27 is 0.28543848262297267 pixels
# Average reprojection error on image 28 is 0.33205398399350794 pixels
# Average reprojection error on image 25 is 0.7291852063555947 pixels
# Average reprojection error across all 4 resected images is 0.44445470250388386 pixels
# Unresected image: 29, resected: 28
# rvec: [[-1.48307443]
#  [ 0.91480588]
#  [ 2.98533931]]
#
# tvec: [[-2.04879346]
#  [-0.08647247]
#  [ 0.72700908]]
# Average error of reprojecting points used to resect image 29 back onto it is: 1.559084893632197
# Fraction of Pnp inliers: 0.9814814814814815 num pts used in Pnp: 108
# Triangulating: 163 points.
# Average reprojection error for just-triangulated points on image 28 is: 17.710402430137616 pixels.
# Average reprojection error for just-triangulated points on image 29 is: 7.994028017570382 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.1101e+04                                    3.06e+06
#        1              2         1.4542e+04      7.66e+04       2.90e+00       2.80e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 9.1101e+04, final cost 1.4542e+04, first-order optimality 2.80e+06.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.4542e+04                                    2.80e+06
#        1              3         1.6897e+03      1.29e+04       7.01e-01       3.45e+05
#        2              4         7.3440e+02      9.55e+02       2.48e-01       1.43e+05
#        3              6         7.0433e+02      3.01e+01       3.53e-01       8.18e+04
# `ftol` termination condition is satisfied.
# Function evaluations 6, initial cost 1.4542e+04, final cost 7.0433e+02, first-order optimality 8.18e+04.
# Average reprojection error on image 26 is 0.3588342637107448 pixels
# Average reprojection error on image 27 is 0.2613514309646777 pixels
# Average reprojection error on image 28 is 0.24050221513958053 pixels
# Average reprojection error on image 25 is 0.4843205680642347 pixels
# Average reprojection error on image 29 is 0.2786410156961363 pixels
# Average reprojection error across all 5 resected images is 0.3247298987150748 pixels
# Unresected image: 24, resected: 25
# rvec: [[ 0.90979507]
#  [-0.8117784 ]
#  [ 2.85669328]]
#
# tvec: [[-1.56239732]
#  [-0.54910815]
#  [-5.24175472]]
# Average error of reprojecting points used to resect image 24 back onto it is: 1.8169000325850992
# Fraction of Pnp inliers: 0.9534883720930233 num pts used in Pnp: 301
# Triangulating: 324 points.
# Average reprojection error for just-triangulated points on image 24 is: 28.906821207309815 pixels.
# Average reprojection error for just-triangulated points on image 25 is: 29.29959570431854 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         7.7265e+05                                    1.83e+07
#        1              2         1.3131e+04      7.60e+05       3.34e+00       1.65e+06
#        2              4         5.4698e+03      7.66e+03       5.33e-01       5.10e+05
#        3              5         1.5962e+03      3.87e+03       5.42e-01       8.49e+04
#        4              7         1.5592e+03      3.70e+01       3.75e-01       7.65e+04
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 7.7265e+05, final cost 1.5592e+03, first-order optimality 7.65e+04.
# Average reprojection error on image 26 is 0.4503883769040612 pixels
# Average reprojection error on image 27 is 0.2967143450922933 pixels
# Average reprojection error on image 28 is 0.24828428249207024 pixels
# Average reprojection error on image 25 is 0.48682999639443375 pixels
# Average reprojection error on image 29 is 0.2822981743923648 pixels
# Average reprojection error on image 24 is 0.5959857532912469 pixels
# Average reprojection error across all 6 resected images is 0.393416821427745 pixels
# Unresected image: 30, resected: 29
# rvec: [[ 1.17639724]
#  [-0.34528603]
#  [-2.54776704]]
#
# tvec: [[-2.39369659]
#  [-0.14979194]
#  [ 0.97792313]]
# Average error of reprojecting points used to resect image 30 back onto it is: 1.0604681859220868
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 91
# Triangulating: 162 points.
# Average reprojection error for just-triangulated points on image 29 is: 18.812510159192026 pixels.
# Average reprojection error for just-triangulated points on image 30 is: 7.479212789780086 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.5137e+04                                    3.25e+06
#        1              2         1.0099e+04      8.50e+04       2.78e+00       2.82e+06
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 9.5137e+04, final cost 1.0099e+04, first-order optimality 2.82e+06.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.0099e+04                                    2.82e+06
#        1              2         3.8266e+03      6.27e+03       1.39e+00       1.72e+06
#        2              3         1.4996e+03      2.33e+03       6.62e-01       3.06e+05
#        3              4         1.4253e+03      7.42e+01       3.70e-01       7.25e+04
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 1.0099e+04, final cost 1.4253e+03, first-order optimality 7.25e+04.
# Average reprojection error on image 26 is 0.4339691880594833 pixels
# Average reprojection error on image 27 is 0.2885279415257061 pixels
# Average reprojection error on image 28 is 0.2498964525827294 pixels
# Average reprojection error on image 25 is 0.48520597507958363 pixels
# Average reprojection error on image 29 is 0.20052963351138126 pixels
# Average reprojection error on image 24 is 0.49862139515873916 pixels
# Average reprojection error on image 30 is 0.1896790133915917 pixels
# Average reprojection error across all 7 resected images is 0.33520422847274495 pixels
# Unresected image: 23, resected: 24
# rvec: [[-1.20033739]
#  [-1.63207765]
#  [-2.6514056 ]]
#
# tvec: [[-2.0174228 ]
#  [-0.36118243]
#  [-5.36836502]]
# Average error of reprojecting points used to resect image 23 back onto it is: 1.6340451656471255
# Fraction of Pnp inliers: 0.9770491803278688 num pts used in Pnp: 305
# Triangulating: 331 points.
# Average reprojection error for just-triangulated points on image 23 is: 28.699236921781633 pixels.
# Average reprojection error for just-triangulated points on image 24 is: 66.50031522789817 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.1572e+06                                    4.27e+07
#        1              2         2.2385e+05      1.93e+06       4.82e+00       8.30e+06
#        2              3         1.1918e+04      2.12e+05       7.84e+00       8.11e+05
#        3              4         4.4777e+03      7.44e+03       1.09e+00       1.49e+06
#        4              5         2.2425e+03      2.24e+03       1.61e+00       4.11e+05
#        5              6         2.0076e+03      2.35e+02       3.60e-01       3.25e+04
#        6              7         2.0039e+03      3.73e+00       3.12e-01       1.20e+04
# `ftol` termination condition is satisfied.
# Function evaluations 7, initial cost 2.1572e+06, final cost 2.0039e+03, first-order optimality 1.20e+04.
# Average reprojection error on image 26 is 0.499953615933444 pixels
# Average reprojection error on image 27 is 0.29872753242075706 pixels
# Average reprojection error on image 28 is 0.24408089830210386 pixels
# Average reprojection error on image 25 is 0.5563741281450211 pixels
# Average reprojection error on image 29 is 0.18993782438849957 pixels
# Average reprojection error on image 24 is 0.33986044243981817 pixels
# Average reprojection error on image 30 is 0.17715486361834742 pixels
# Average reprojection error on image 23 is 0.41998493077771754 pixels
# Average reprojection error across all 8 resected images is 0.34075927950321355 pixels
# Unresected image: 31, resected: 30
# rvec: [[0.0388895 ]
#  [0.94976757]
#  [0.34658086]]
#
# tvec: [[-2.88014136]
#  [-0.38054013]
#  [ 2.62746752]]
# Average error of reprojecting points used to resect image 31 back onto it is: 0.7250673200004214
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 54
# Triangulating: 146 points.
# Average reprojection error for just-triangulated points on image 30 is: 8.17476422579906 pixels.
# Average reprojection error for just-triangulated points on image 31 is: 3.1932082390858794 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.7782e+04                                    8.13e+05
#        1              2         2.0599e+03      1.57e+04       1.18e+00       3.72e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 1.7782e+04, final cost 2.0599e+03, first-order optimality 3.72e+04.
# Average reprojection error on image 26 is 0.5009839558458052 pixels
# Average reprojection error on image 27 is 0.2985104691102004 pixels
# Average reprojection error on image 28 is 0.24656491147954854 pixels
# Average reprojection error on image 25 is 0.5567435360724367 pixels
# Average reprojection error on image 29 is 0.20356104493038446 pixels
# Average reprojection error on image 24 is 0.3374691178244489 pixels
# Average reprojection error on image 30 is 0.18907797533300988 pixels
# Average reprojection error on image 23 is 0.4178876128230757 pixels
# Average reprojection error on image 31 is 0.34053515817206714 pixels
# Average reprojection error across all 9 resected images is 0.34348153128788633 pixels
# Unresected image: 22, resected: 23
# rvec: [[  2494079.23941283]
#  [-35712287.94125798]
#  [ -4034067.22063696]]
#
# tvec: [[-2.49874492]
#  [-0.08572592]
#  [-6.53648166]]
# Average error of reprojecting points used to resect image 22 back onto it is: 1.0304225514900367
# Fraction of Pnp inliers: 0.9857651245551602 num pts used in Pnp: 281
# Triangulating: 315 points.
# Average reprojection error for just-triangulated points on image 22 is: 14.072318975155016 pixels.
# Average reprojection error for just-triangulated points on image 23 is: 21.893408114544478 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.0559e+05                                    8.20e+06
#        1              2         9.8281e+03      2.96e+05       5.26e+00       8.29e+05
#        2              3         2.4510e+03      7.38e+03       1.64e+00       6.21e+04
#        3              4         2.4310e+03      2.00e+01       5.44e-01       2.30e+04
# `ftol` termination condition is satisfied.
# Function evaluations 4, initial cost 3.0559e+05, final cost 2.4310e+03, first-order optimality 2.30e+04.
# Average reprojection error on image 26 is 0.5296559491688791 pixels
# Average reprojection error on image 27 is 0.3066291521259038 pixels
# Average reprojection error on image 28 is 0.2473548001739443 pixels
# Average reprojection error on image 25 is 0.5830994118300113 pixels
# Average reprojection error on image 29 is 0.20309419012469337 pixels
# Average reprojection error on image 24 is 0.37490840477339743 pixels
# Average reprojection error on image 30 is 0.15084416054069205 pixels
# Average reprojection error on image 23 is 0.30405945656011935 pixels
# Average reprojection error on image 31 is 0.15194683433026163 pixels
# Average reprojection error on image 22 is 0.371284426918126 pixels
# Average reprojection error across all 10 resected images is 0.32228767865460284 pixels
# Unresected image: 32, resected: 31
# rvec: [[ 1.37192539]
#  [-0.14048728]
#  [-2.33386214]]
#
# tvec: [[-3.16738311]
#  [-0.5474745 ]
#  [ 3.20593737]]
# Average error of reprojecting points used to resect image 32 back onto it is: 1.3301371085331053
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 69
# Triangulating: 190 points.
# Average reprojection error for just-triangulated points on image 31 is: 4.714245098867644 pixels.
# Average reprojection error for just-triangulated points on image 32 is: 1.4477264565999985 pixels.
# Average reprojection error on image 26 is 0.5296559491688791 pixels
# Average reprojection error on image 27 is 0.3066291521259038 pixels
# Average reprojection error on image 28 is 0.2473548001739443 pixels
# Average reprojection error on image 25 is 0.5830994118300113 pixels
# Average reprojection error on image 29 is 0.20309419012469337 pixels
# Average reprojection error on image 24 is 0.37490840477339743 pixels
# Average reprojection error on image 30 is 0.15084416054069205 pixels
# Average reprojection error on image 23 is 0.30405945656011935 pixels
# Average reprojection error on image 31 is 2.374604963207446 pixels
# Average reprojection error on image 22 is 0.371284426918126 pixels
# Average reprojection error on image 32 is 1.4163995646439527 pixels
# Average reprojection error across all 11 resected images is 0.6238122254606515 pixels
# Unresected image: 21, resected: 22
# rvec: [[1.28598473]
#  [0.17423557]
#  [2.42832735]]
#
# tvec: [[-2.8054328 ]
#  [ 0.12996524]
#  [-6.41702884]]
# Average error of reprojecting points used to resect image 21 back onto it is: 1.0327244504594133
# Fraction of Pnp inliers: 0.9925925925925926 num pts used in Pnp: 270
# Triangulating: 274 points.
# Average reprojection error for just-triangulated points on image 21 is: 1.7230607782539966 pixels.
# Average reprojection error for just-triangulated points on image 22 is: 4.368128210720183 pixels.
# Average reprojection error on image 26 is 0.5296559491688791 pixels
# Average reprojection error on image 27 is 0.3066291521259038 pixels
# Average reprojection error on image 28 is 0.2473548001739443 pixels
# Average reprojection error on image 25 is 0.5830994118300113 pixels
# Average reprojection error on image 29 is 0.20309419012469337 pixels
# Average reprojection error on image 24 is 0.37490840477339743 pixels
# Average reprojection error on image 30 is 0.15084416054069205 pixels
# Average reprojection error on image 23 is 0.30405945656011935 pixels
# Average reprojection error on image 31 is 2.374604963207446 pixels
# Average reprojection error on image 22 is 1.630060515150038 pixels
# Average reprojection error on image 32 is 1.4163995646439527 pixels
# Average reprojection error on image 21 is 1.3804306155619166 pixels
# Average reprojection error across all 12 resected images is 0.7917617653217496 pixels
# Unresected image: 33, resected: 32
# rvec: [[0.02235659]
#  [1.23133063]
#  [0.48125239]]
#
# tvec: [[-3.24346195]
#  [-0.81592162]
#  [ 3.56552434]]
# Average error of reprojecting points used to resect image 33 back onto it is: 2.2991871950986225
# Fraction of Pnp inliers: 0.8902439024390244 num pts used in Pnp: 82
# Triangulating: 206 points.
# Average reprojection error for just-triangulated points on image 32 is: 1.0710252748242735 pixels.
# Average reprojection error for just-triangulated points on image 33 is: 1.0718473477578285 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.1823e+04                                    8.76e+05
#        1              2         4.7475e+03      1.71e+04       2.29e+00       6.11e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.1823e+04, final cost 4.7475e+03, first-order optimality 6.11e+05.
# Average reprojection error on image 26 is 0.5418290595583981 pixels
# Average reprojection error on image 27 is 0.31101187823433196 pixels
# Average reprojection error on image 28 is 0.2492561525634826 pixels
# Average reprojection error on image 25 is 0.5941144928525216 pixels
# Average reprojection error on image 29 is 0.21125410894341368 pixels
# Average reprojection error on image 24 is 0.3920799519962726 pixels
# Average reprojection error on image 30 is 0.17254989358323028 pixels
# Average reprojection error on image 23 is 0.329920672980356 pixels
# Average reprojection error on image 31 is 0.36050979497019764 pixels
# Average reprojection error on image 22 is 0.2761971791572312 pixels
# Average reprojection error on image 32 is 1.111082011026339 pixels
# Average reprojection error on image 21 is 0.3653945646300589 pixels
# Average reprojection error on image 33 is 1.8265170861356324 pixels
# Average reprojection error across all 13 resected images is 0.5185936035870358 pixels
# Unresected image: 20, resected: 21
# rvec: [[1.41761812]
#  [0.18696783]
#  [2.27780072]]
#
# tvec: [[-3.0398499 ]
#  [ 0.30862423]
#  [-6.04656491]]
# Average error of reprojecting points used to resect image 20 back onto it is: 1.1307059631888914
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 238
# Triangulating: 293 points.
# Average reprojection error for just-triangulated points on image 20 is: 0.9842552465482969 pixels.
# Average reprojection error for just-triangulated points on image 21 is: 1.6525998364566852 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.8928e+03                                    6.11e+05
#        1              2         3.6929e+03      3.20e+03       5.67e-01       1.97e+05
#        2              3         3.1645e+03      5.28e+02       7.79e-02       5.08e+03
#        3              5         3.1642e+03      3.35e-01       3.55e-02       1.48e+03
# `ftol` termination condition is satisfied.
# Function evaluations 5, initial cost 6.8928e+03, final cost 3.1642e+03, first-order optimality 1.48e+03.
# Average reprojection error on image 26 is 0.5484935827073742 pixels
# Average reprojection error on image 27 is 0.31301890747492894 pixels
# Average reprojection error on image 28 is 0.2503465797143024 pixels
# Average reprojection error on image 25 is 0.6022822066849027 pixels
# Average reprojection error on image 29 is 0.20969934469102172 pixels
# Average reprojection error on image 24 is 0.4060538608652219 pixels
# Average reprojection error on image 30 is 0.16711830634555094 pixels
# Average reprojection error on image 23 is 0.3517108816697331 pixels
# Average reprojection error on image 31 is 0.1325781151761013 pixels
# Average reprojection error on image 22 is 0.3057477647551563 pixels
# Average reprojection error on image 32 is 0.10313836149497971 pixels
# Average reprojection error on image 21 is 0.2603055814379848 pixels
# Average reprojection error on image 33 is 0.10372841031642861 pixels
# Average reprojection error on image 20 is 0.3348978360924121 pixels
# Average reprojection error across all 14 resected images is 0.2920799813875785 pixels
# Unresected image: 34, resected: 33
# rvec: [[ 1.84941993]
#  [ 0.76146558]
#  [-2.31274651]]
#
# tvec: [[-3.33516389]
#  [-1.13739267]
#  [ 4.42494061]]
# Average error of reprojecting points used to resect image 34 back onto it is: 0.5457354140156964
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 145
# Triangulating: 226 points.
# Average reprojection error for just-triangulated points on image 33 is: 4.606105563992053 pixels.
# Average reprojection error for just-triangulated points on image 34 is: 2.335704555297011 pixels.
# Average reprojection error on image 26 is 0.5484935827073742 pixels
# Average reprojection error on image 27 is 0.31301890747492894 pixels
# Average reprojection error on image 28 is 0.2503465797143024 pixels
# Average reprojection error on image 25 is 0.6022822066849027 pixels
# Average reprojection error on image 29 is 0.20969934469102172 pixels
# Average reprojection error on image 24 is 0.4060538608652219 pixels
# Average reprojection error on image 30 is 0.16711830634555094 pixels
# Average reprojection error on image 23 is 0.3517108816697331 pixels
# Average reprojection error on image 31 is 0.1325781151761013 pixels
# Average reprojection error on image 22 is 0.3057477647551563 pixels
# Average reprojection error on image 32 is 0.10313836149497971 pixels
# Average reprojection error on image 21 is 0.2603055814379848 pixels
# Average reprojection error on image 33 is 2.0833728397535713 pixels
# Average reprojection error on image 20 is 0.3348978360924121 pixels
# Average reprojection error on image 34 is 1.6361209286506786 pixels
# Average reprojection error across all 15 resected images is 0.513659006500928 pixels
# Unresected image: 19, resected: 20
# rvec: [[1.53779153]
#  [0.18850604]
#  [2.12555499]]
#
# tvec: [[-3.20405306]
#  [ 0.53002715]
#  [-5.68805039]]
# Average error of reprojecting points used to resect image 19 back onto it is: 0.9214588326978652
# Fraction of Pnp inliers: 0.9960159362549801 num pts used in Pnp: 251
# Triangulating: 262 points.
# Average reprojection error for just-triangulated points on image 19 is: 1.095947480937345 pixels.
# Average reprojection error for just-triangulated points on image 20 is: 1.6038825052648302 pixels.
# Average reprojection error on image 26 is 0.5484935827073742 pixels
# Average reprojection error on image 27 is 0.31301890747492894 pixels
# Average reprojection error on image 28 is 0.2503465797143024 pixels
# Average reprojection error on image 25 is 0.6022822066849027 pixels
# Average reprojection error on image 29 is 0.20969934469102172 pixels
# Average reprojection error on image 24 is 0.4060538608652219 pixels
# Average reprojection error on image 30 is 0.16711830634555094 pixels
# Average reprojection error on image 23 is 0.3517108816697331 pixels
# Average reprojection error on image 31 is 0.1325781151761013 pixels
# Average reprojection error on image 22 is 0.3057477647551563 pixels
# Average reprojection error on image 32 is 0.10313836149497971 pixels
# Average reprojection error on image 21 is 0.2603055814379848 pixels
# Average reprojection error on image 33 is 2.0833728397535713 pixels
# Average reprojection error on image 20 is 0.7546882190762165 pixels
# Average reprojection error on image 34 is 1.6361209286506786 pixels
# Average reprojection error on image 19 is 1.0102310859697696 pixels
# Average reprojection error across all 16 resected images is 0.5709316604042184 pixels
# Unresected image: 35, resected: 34
# rvec: [[-0.15849022]
#  [ 1.89116416]
#  [ 0.45466942]]
#
# tvec: [[-3.27115329]
#  [-1.37460103]
#  [ 4.46408085]]
# Average error of reprojecting points used to resect image 35 back onto it is: 1.2821559169800478
# Fraction of Pnp inliers: 0.9736842105263158 num pts used in Pnp: 152
# Triangulating: 236 points.
# Average reprojection error for just-triangulated points on image 34 is: 0.41999580900332345 pixels.
# Average reprojection error for just-triangulated points on image 35 is: 0.4270131754877483 pixels.
# Average reprojection error on image 26 is 0.5484935827073742 pixels
# Average reprojection error on image 27 is 0.31301890747492894 pixels
# Average reprojection error on image 28 is 0.2503465797143024 pixels
# Average reprojection error on image 25 is 0.6022822066849027 pixels
# Average reprojection error on image 29 is 0.20969934469102172 pixels
# Average reprojection error on image 24 is 0.4060538608652219 pixels
# Average reprojection error on image 30 is 0.16711830634555094 pixels
# Average reprojection error on image 23 is 0.3517108816697331 pixels
# Average reprojection error on image 31 is 0.1325781151761013 pixels
# Average reprojection error on image 22 is 0.3057477647551563 pixels
# Average reprojection error on image 32 is 0.10313836149497971 pixels
# Average reprojection error on image 21 is 0.2603055814379848 pixels
# Average reprojection error on image 33 is 2.0833728397535713 pixels
# Average reprojection error on image 20 is 0.7546882190762165 pixels
# Average reprojection error on image 34 is 1.1632946877334196 pixels
# Average reprojection error on image 19 is 1.0102310859697696 pixels
# Average reprojection error on image 35 is 0.7620175484434868 pixels
# Average reprojection error across all 17 resected images is 0.5543586984702189 pixels
# Unresected image: 18, resected: 19
# rvec: [[1.67101073]
#  [0.16509574]
#  [1.96942225]]
#
# tvec: [[-3.31888604]
#  [ 0.79825179]
#  [-5.21431319]]
# Average error of reprojecting points used to resect image 18 back onto it is: 1.6890631851682556
# Fraction of Pnp inliers: 0.9646017699115044 num pts used in Pnp: 226
# Triangulating: 205 points.
# Average reprojection error for just-triangulated points on image 18 is: 0.34207863354872425 pixels.
# Average reprojection error for just-triangulated points on image 19 is: 0.31920169531182646 pixels.
# Average reprojection error on image 26 is 0.5484935827073742 pixels
# Average reprojection error on image 27 is 0.31301890747492894 pixels
# Average reprojection error on image 28 is 0.2503465797143024 pixels
# Average reprojection error on image 25 is 0.6022822066849027 pixels
# Average reprojection error on image 29 is 0.20969934469102172 pixels
# Average reprojection error on image 24 is 0.4060538608652219 pixels
# Average reprojection error on image 30 is 0.16711830634555094 pixels
# Average reprojection error on image 23 is 0.3517108816697331 pixels
# Average reprojection error on image 31 is 0.1325781151761013 pixels
# Average reprojection error on image 22 is 0.3057477647551563 pixels
# Average reprojection error on image 32 is 0.10313836149497971 pixels
# Average reprojection error on image 21 is 0.2603055814379848 pixels
# Average reprojection error on image 33 is 2.0833728397535713 pixels
# Average reprojection error on image 20 is 0.7546882190762165 pixels
# Average reprojection error on image 34 is 1.1632946877334196 pixels
# Average reprojection error on image 19 is 0.8121037781587508 pixels
# Average reprojection error on image 35 is 0.7620175484434868 pixels
# Average reprojection error on image 18 is 1.0483860782494636 pixels
# Average reprojection error across all 18 resected images is 0.5707975913573426 pixels
# Unresected image: 0, resected: 35
# rvec: [[0.06634925]
#  [1.62318545]
#  [0.79886719]]
#
# tvec: [[-3.17713383]
#  [-1.61176759]
#  [ 4.70692018]]
# Average error of reprojecting points used to resect image 0 back onto it is: 1.5097684416055246
# Fraction of Pnp inliers: 0.9192546583850931 num pts used in Pnp: 161
# Triangulating: 320 points.
# Average reprojection error for just-triangulated points on image 0 is: 0.18937550047121404 pixels.
# Average reprojection error for just-triangulated points on image 35 is: 0.20365713522301282 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.7181e+04                                    7.02e+05
#        1              3         8.2076e+03      8.97e+03       6.56e-01       3.86e+05
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.7181e+04, final cost 8.2076e+03, first-order optimality 3.86e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         8.2076e+03                                    3.86e+05
#        1              3         5.7409e+03      2.47e+03       4.01e-01       1.49e+05
#        2              4         4.3355e+03      1.41e+03       6.84e-01       3.01e+05
#        3              5         3.9545e+03      3.81e+02       2.16e-01       3.97e+04
# `ftol` termination condition is satisfied.
# Function evaluations 5, initial cost 8.2076e+03, final cost 3.9545e+03, first-order optimality 3.97e+04.
# Average reprojection error on image 26 is 0.5525314343234756 pixels
# Average reprojection error on image 27 is 0.31485537089769755 pixels
# Average reprojection error on image 28 is 0.251970694091757 pixels
# Average reprojection error on image 25 is 0.6092064085942732 pixels
# Average reprojection error on image 29 is 0.21223582700604743 pixels
# Average reprojection error on image 24 is 0.4165860551235232 pixels
# Average reprojection error on image 30 is 0.17392831009529616 pixels
# Average reprojection error on image 23 is 0.36986906495264454 pixels
# Average reprojection error on image 31 is 0.14879311564989986 pixels
# Average reprojection error on image 22 is 0.3358567445203424 pixels
# Average reprojection error on image 32 is 0.13907857711385904 pixels
# Average reprojection error on image 21 is 0.3113065287926621 pixels
# Average reprojection error on image 33 is 0.13922829631923545 pixels
# Average reprojection error on image 20 is 0.28794161448265443 pixels
# Average reprojection error on image 34 is 0.12637682110192724 pixels
# Average reprojection error on image 19 is 0.2698348432071972 pixels
# Average reprojection error on image 35 is 0.09476159104694651 pixels
# Average reprojection error on image 18 is 0.39225440513617404 pixels
# Average reprojection error on image 0 is 0.18654242744758337 pixels
# Average reprojection error across all 19 resected images is 0.2806925331527998 pixels
# Unresected image: 17, resected: 18
# rvec: [[-2.96281036]
#  [-0.91102887]
#  [-1.90882612]]
#
# tvec: [[-3.34119702]
#  [ 1.04358259]
#  [-4.77964201]]
# Average error of reprojecting points used to resect image 17 back onto it is: 1.2622059317996173
# Fraction of Pnp inliers: 0.9655172413793104 num pts used in Pnp: 174
# Triangulating: 195 points.
# Average reprojection error for just-triangulated points on image 17 is: 0.541756472143944 pixels.
# Average reprojection error for just-triangulated points on image 18 is: 0.7387786720103178 pixels.
# Average reprojection error on image 26 is 0.5525314343234756 pixels
# Average reprojection error on image 27 is 0.31485537089769755 pixels
# Average reprojection error on image 28 is 0.251970694091757 pixels
# Average reprojection error on image 25 is 0.6092064085942732 pixels
# Average reprojection error on image 29 is 0.21223582700604743 pixels
# Average reprojection error on image 24 is 0.4165860551235232 pixels
# Average reprojection error on image 30 is 0.17392831009529616 pixels
# Average reprojection error on image 23 is 0.36986906495264454 pixels
# Average reprojection error on image 31 is 0.14879311564989986 pixels
# Average reprojection error on image 22 is 0.3358567445203424 pixels
# Average reprojection error on image 32 is 0.13907857711385904 pixels
# Average reprojection error on image 21 is 0.3113065287926621 pixels
# Average reprojection error on image 33 is 0.13922829631923545 pixels
# Average reprojection error on image 20 is 0.28794161448265443 pixels
# Average reprojection error on image 34 is 0.12637682110192724 pixels
# Average reprojection error on image 19 is 0.2698348432071972 pixels
# Average reprojection error on image 35 is 0.09476159104694651 pixels
# Average reprojection error on image 18 is 0.5001972678206118 pixels
# Average reprojection error on image 0 is 0.18654242744758337 pixels
# Average reprojection error on image 17 is 0.8779751059062473 pixels
# Average reprojection error across all 20 resected images is 0.31595380492469405 pixels
# Unresected image: 1, resected: 0
# rvec: [[-0.00304611]
#  [ 1.82483564]
#  [ 0.81314141]]
#
# tvec: [[-2.92841115]
#  [-1.88543465]
#  [ 5.56003189]]
# Average error of reprojecting points used to resect image 1 back onto it is: 0.609911862988588
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 251
# Triangulating: 275 points.
# Average reprojection error for just-triangulated points on image 0 is: 5.756389465844015 pixels.
# Average reprojection error for just-triangulated points on image 1 is: 3.2460179528135353 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         2.0686e+04                                    1.65e+06
#        1              2         6.1487e+03      1.45e+04       1.55e+00       5.77e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 2.0686e+04, final cost 6.1487e+03, first-order optimality 5.77e+05.
# Average reprojection error on image 26 is 0.5514498114161629 pixels
# Average reprojection error on image 27 is 0.315230121444268 pixels
# Average reprojection error on image 28 is 0.25271051864586547 pixels
# Average reprojection error on image 25 is 0.610361059906676 pixels
# Average reprojection error on image 29 is 0.21441194067251462 pixels
# Average reprojection error on image 24 is 0.4212506368846586 pixels
# Average reprojection error on image 30 is 0.17320833642038957 pixels
# Average reprojection error on image 23 is 0.3763201463744457 pixels
# Average reprojection error on image 31 is 0.16602056539815213 pixels
# Average reprojection error on image 22 is 0.34381428380575285 pixels
# Average reprojection error on image 32 is 0.2719778557425979 pixels
# Average reprojection error on image 21 is 0.33725162680573934 pixels
# Average reprojection error on image 33 is 0.2789208390133058 pixels
# Average reprojection error on image 20 is 0.3245777254918164 pixels
# Average reprojection error on image 34 is 0.18086530842869258 pixels
# Average reprojection error on image 19 is 0.3056421104745291 pixels
# Average reprojection error on image 35 is 0.10168423982947589 pixels
# Average reprojection error on image 18 is 0.28689347666879794 pixels
# Average reprojection error on image 0 is 0.43716420756795116 pixels
# Average reprojection error on image 17 is 0.4429914126442606 pixels
# Average reprojection error on image 1 is 1.2754902476273013 pixels
# Average reprojection error across all 21 resected images is 0.36515411767920725 pixels
# Unresected image: 16, resected: 17
# rvec: [[1.88421224]
#  [0.12133549]
#  [1.63593322]]
#
# tvec: [[-3.27984161]
#  [ 1.3131392 ]
#  [-4.41590512]]
# Average error of reprojecting points used to resect image 16 back onto it is: 1.2584404126899238
# Fraction of Pnp inliers: 0.9745222929936306 num pts used in Pnp: 157
# Triangulating: 180 points.
# Average reprojection error for just-triangulated points on image 16 is: 0.6535739315244904 pixels.
# Average reprojection error for just-triangulated points on image 17 is: 3.259478000084242 pixels.
# Average reprojection error on image 26 is 0.5514498114161629 pixels
# Average reprojection error on image 27 is 0.315230121444268 pixels
# Average reprojection error on image 28 is 0.25271051864586547 pixels
# Average reprojection error on image 25 is 0.610361059906676 pixels
# Average reprojection error on image 29 is 0.21441194067251462 pixels
# Average reprojection error on image 24 is 0.4212506368846586 pixels
# Average reprojection error on image 30 is 0.17320833642038957 pixels
# Average reprojection error on image 23 is 0.3763201463744457 pixels
# Average reprojection error on image 31 is 0.16602056539815213 pixels
# Average reprojection error on image 22 is 0.34381428380575285 pixels
# Average reprojection error on image 32 is 0.2719778557425979 pixels
# Average reprojection error on image 21 is 0.33725162680573934 pixels
# Average reprojection error on image 33 is 0.2789208390133058 pixels
# Average reprojection error on image 20 is 0.3245777254918164 pixels
# Average reprojection error on image 34 is 0.18086530842869258 pixels
# Average reprojection error on image 19 is 0.3056421104745291 pixels
# Average reprojection error on image 35 is 0.10168423982947589 pixels
# Average reprojection error on image 18 is 0.28689347666879794 pixels
# Average reprojection error on image 0 is 0.43716420756795116 pixels
# Average reprojection error on image 17 is 1.3715034744376604 pixels
# Average reprojection error on image 1 is 1.2754902476273013 pixels
# Average reprojection error on image 16 is 0.9342085732612259 pixels
# Average reprojection error across all 22 resected images is 0.43322532301445354 pixels
# Unresected image: 2, resected: 1
# rvec: [[1.05959241e-04]
#  [1.96583685e+00]
#  [9.15736418e-01]]
#
# tvec: [[-2.57694214]
#  [-2.09989783]
#  [ 6.05850973]]
# Average error of reprojecting points used to resect image 2 back onto it is: 0.8918835711556733
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 250
# Triangulating: 284 points.
# Average reprojection error for just-triangulated points on image 1 is: 6.656619325399984 pixels.
# Average reprojection error for just-triangulated points on image 2 is: 0.5394368334903825 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         3.2454e+04                                    2.32e+06
#        1              2         4.7193e+03      2.77e+04       2.41e+00       4.27e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 3.2454e+04, final cost 4.7193e+03, first-order optimality 4.27e+04.
# Average reprojection error on image 26 is 0.5514808193847188 pixels
# Average reprojection error on image 27 is 0.3154571907700112 pixels
# Average reprojection error on image 28 is 0.25341122674223454 pixels
# Average reprojection error on image 25 is 0.6117675910903453 pixels
# Average reprojection error on image 29 is 0.21517711039535203 pixels
# Average reprojection error on image 24 is 0.4239205229634987 pixels
# Average reprojection error on image 30 is 0.1730473709368227 pixels
# Average reprojection error on image 23 is 0.38050300342906074 pixels
# Average reprojection error on image 31 is 0.1398384168578264 pixels
# Average reprojection error on image 22 is 0.34912693148490814 pixels
# Average reprojection error on image 32 is 0.12744722443545947 pixels
# Average reprojection error on image 21 is 0.33197686931158854 pixels
# Average reprojection error on image 33 is 0.10334168612428102 pixels
# Average reprojection error on image 20 is 0.3294265103914358 pixels
# Average reprojection error on image 34 is 0.1151086194456172 pixels
# Average reprojection error on image 19 is 0.32317748178146105 pixels
# Average reprojection error on image 35 is 0.1038247269476298 pixels
# Average reprojection error on image 18 is 0.309416727038168 pixels
# Average reprojection error on image 0 is 0.10093862102788229 pixels
# Average reprojection error on image 17 is 0.3481798138290447 pixels
# Average reprojection error on image 1 is 0.15448547258460513 pixels
# Average reprojection error on image 16 is 0.43181850012127987 pixels
# Average reprojection error on image 2 is 0.17706501239967945 pixels
# Average reprojection error across all 23 resected images is 0.27695380215186566 pixels
# Unresected image: 15, resected: 16
# rvec: [[1.97538984]
#  [0.11894489]
#  [1.46263771]]
#
# tvec: [[-3.14205098]
#  [ 1.55786504]
#  [-3.97581608]]
# Average error of reprojecting points used to resect image 15 back onto it is: 1.1373466506885004
# Fraction of Pnp inliers: 0.9747899159663865 num pts used in Pnp: 119
# Triangulating: 147 points.
# Average reprojection error for just-triangulated points on image 15 is: 0.21990170926159452 pixels.
# Average reprojection error for just-triangulated points on image 16 is: 0.2809742426438457 pixels.
# Average reprojection error on image 26 is 0.5514808193847188 pixels
# Average reprojection error on image 27 is 0.3154571907700112 pixels
# Average reprojection error on image 28 is 0.25341122674223454 pixels
# Average reprojection error on image 25 is 0.6117675910903453 pixels
# Average reprojection error on image 29 is 0.21517711039535203 pixels
# Average reprojection error on image 24 is 0.4239205229634987 pixels
# Average reprojection error on image 30 is 0.1730473709368227 pixels
# Average reprojection error on image 23 is 0.38050300342906074 pixels
# Average reprojection error on image 31 is 0.1398384168578264 pixels
# Average reprojection error on image 22 is 0.34912693148490814 pixels
# Average reprojection error on image 32 is 0.12744722443545947 pixels
# Average reprojection error on image 21 is 0.33197686931158854 pixels
# Average reprojection error on image 33 is 0.10334168612428102 pixels
# Average reprojection error on image 20 is 0.3294265103914358 pixels
# Average reprojection error on image 34 is 0.1151086194456172 pixels
# Average reprojection error on image 19 is 0.32317748178146105 pixels
# Average reprojection error on image 35 is 0.1038247269476298 pixels
# Average reprojection error on image 18 is 0.309416727038168 pixels
# Average reprojection error on image 0 is 0.10093862102788229 pixels
# Average reprojection error on image 17 is 0.3481798138290447 pixels
# Average reprojection error on image 1 is 0.15448547258460513 pixels
# Average reprojection error on image 16 is 0.3859093782803215 pixels
# Average reprojection error on image 2 is 0.17706501239967945 pixels
# Average reprojection error on image 15 is 0.623684382334976 pixels
# Average reprojection error across all 24 resected images is 0.2894880295827887 pixels
# Unresected image: 3, resected: 2
# rvec: [[-0.01538867]
#  [ 2.16962182]
#  [ 0.97236265]]
#
# tvec: [[-2.17717401]
#  [-2.28732552]
#  [ 6.46832797]]
# Average error of reprojecting points used to resect image 3 back onto it is: 0.5924711564122783
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 257
# Triangulating: 223 points.
# Average reprojection error for just-triangulated points on image 2 is: 0.5357596403179674 pixels.
# Average reprojection error for just-triangulated points on image 3 is: 0.11643276696589677 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         5.3323e+03                                    1.36e+05
#        1              2         4.9822e+03      3.50e+02       2.08e-01       1.16e+04
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 5.3323e+03, final cost 4.9822e+03, first-order optimality 1.16e+04.
# Average reprojection error on image 26 is 0.5507789867819914 pixels
# Average reprojection error on image 27 is 0.3155005560072424 pixels
# Average reprojection error on image 28 is 0.2537323410198642 pixels
# Average reprojection error on image 25 is 0.612525512374386 pixels
# Average reprojection error on image 29 is 0.21523861320795254 pixels
# Average reprojection error on image 24 is 0.4258457853382518 pixels
# Average reprojection error on image 30 is 0.1730399043571008 pixels
# Average reprojection error on image 23 is 0.3824052398234 pixels
# Average reprojection error on image 31 is 0.14004816893635413 pixels
# Average reprojection error on image 22 is 0.3519135418264932 pixels
# Average reprojection error on image 32 is 0.12774885934001953 pixels
# Average reprojection error on image 21 is 0.3363749093869195 pixels
# Average reprojection error on image 33 is 0.1054127578973145 pixels
# Average reprojection error on image 20 is 0.3371844824871867 pixels
# Average reprojection error on image 34 is 0.12111612695364865 pixels
# Average reprojection error on image 19 is 0.3328769990181296 pixels
# Average reprojection error on image 35 is 0.10797832972117398 pixels
# Average reprojection error on image 18 is 0.3214543646963158 pixels
# Average reprojection error on image 0 is 0.1068498808797016 pixels
# Average reprojection error on image 17 is 0.34384599296490215 pixels
# Average reprojection error on image 1 is 0.11269292569771173 pixels
# Average reprojection error on image 16 is 0.31658649000044126 pixels
# Average reprojection error on image 2 is 0.09761351165132967 pixels
# Average reprojection error on image 15 is 0.407612489376289 pixels
# Average reprojection error on image 3 is 0.1356039549149153 pixels
# Average reprojection error across all 25 resected images is 0.26927922898636136 pixels
# Unresected image: 14, resected: 15
# rvec: [[ 0.10005872]
#  [-1.83982096]
#  [-0.82350455]]
#
# tvec: [[-2.9424369 ]
#  [ 1.77423551]
#  [-3.59769169]]
# Average error of reprojecting points used to resect image 14 back onto it is: 1.1029760441518337
# Fraction of Pnp inliers: 0.9888888888888889 num pts used in Pnp: 90
# Triangulating: 146 points.
# Average reprojection error for just-triangulated points on image 14 is: 0.23156010972881771 pixels.
# Average reprojection error for just-triangulated points on image 15 is: 0.49001352442261825 pixels.
# Average reprojection error on image 26 is 0.5507789867819914 pixels
# Average reprojection error on image 27 is 0.3155005560072424 pixels
# Average reprojection error on image 28 is 0.2537323410198642 pixels
# Average reprojection error on image 25 is 0.612525512374386 pixels
# Average reprojection error on image 29 is 0.21523861320795254 pixels
# Average reprojection error on image 24 is 0.4258457853382518 pixels
# Average reprojection error on image 30 is 0.1730399043571008 pixels
# Average reprojection error on image 23 is 0.3824052398234 pixels
# Average reprojection error on image 31 is 0.14004816893635413 pixels
# Average reprojection error on image 22 is 0.3519135418264932 pixels
# Average reprojection error on image 32 is 0.12774885934001953 pixels
# Average reprojection error on image 21 is 0.3363749093869195 pixels
# Average reprojection error on image 33 is 0.1054127578973145 pixels
# Average reprojection error on image 20 is 0.3371844824871867 pixels
# Average reprojection error on image 34 is 0.12111612695364865 pixels
# Average reprojection error on image 19 is 0.3328769990181296 pixels
# Average reprojection error on image 35 is 0.10797832972117398 pixels
# Average reprojection error on image 18 is 0.3214543646963158 pixels
# Average reprojection error on image 0 is 0.1068498808797016 pixels
# Average reprojection error on image 17 is 0.34384599296490215 pixels
# Average reprojection error on image 1 is 0.11269292569771173 pixels
# Average reprojection error on image 16 is 0.31658649000044126 pixels
# Average reprojection error on image 2 is 0.09761351165132967 pixels
# Average reprojection error on image 15 is 0.4369552969781526 pixels
# Average reprojection error on image 3 is 0.1356039549149153 pixels
# ...
# Average reprojection error on image 26 is 0.5507789867819914 pixels
# Average reprojection error on image 27 is 0.3155005560072424 pixels
# Average reprojection error on image 28 is 0.2537323410198642 pixels
# Average reprojection error on image 25 is 0.612525512374386 pixels
# Average reprojection error on image 29 is 0.21523861320795254 pixels
# Average reprojection error on image 24 is 0.4258457853382518 pixels
# Average reprojection error on image 30 is 0.1730399043571008 pixels
# Average reprojection error on image 23 is 0.3824052398234 pixels
# Average reprojection error on image 31 is 0.14004816893635413 pixels
# Average reprojection error on image 22 is 0.3519135418264932 pixels
# Average reprojection error on image 32 is 0.12774885934001953 pixels
# Average reprojection error on image 21 is 0.3363749093869195 pixels
# Average reprojection error on image 33 is 0.1054127578973145 pixels
# Average reprojection error on image 20 is 0.3371844824871867 pixels
# Average reprojection error on image 34 is 0.12111612695364865 pixels
# Average reprojection error on image 19 is 0.3328769990181296 pixels
# Average reprojection error on image 35 is 0.10797832972117398 pixels
# Average reprojection error on image 18 is 0.3214543646963158 pixels
# Average reprojection error on image 0 is 0.1068498808797016 pixels
# Average reprojection error on image 17 is 0.34384599296490215 pixels
# Average reprojection error on image 1 is 0.11269292569771173 pixels
# Average reprojection error on image 16 is 0.31658649000044126 pixels
# Average reprojection error on image 2 is 0.09761351165132967 pixels
# Average reprojection error on image 15 is 0.4369552969781526 pixels
# Average reprojection error on image 3 is 0.35862662530825146 pixels
# Average reprojection error on image 14 is 0.4804092134684096 pixels
# Average reprojection error on image 4 is 0.3195426552414508 pixels
# Average reprojection error on image 13 is 0.44466344088566745 pixels
# Average reprojection error on image 5 is 0.43714102545217337 pixels
# Average reprojection error on image 12 is 0.5438980459567906 pixels
# Average reprojection error on image 6 is 0.7690653444023883 pixels
# Average reprojection error on image 11 is 0.8418964701315451 pixels
# Average reprojection error across all 32 resected images is 0.3381550749435206 pixels
# Unresected image: 7, resected: 6
# rvec: [[-0.36222735]
#  [ 2.26589425]
#  [-1.09630639]]
#
# tvec: [[-0.14768647]
#  [-2.69543485]
#  [ 7.1480233 ]]
# Average error of reprojecting points used to resect image 7 back onto it is: 1.3504892245850155
# Fraction of Pnp inliers: 0.972972972972973 num pts used in Pnp: 148
# Triangulating: 204 points.
# Average reprojection error for just-triangulated points on image 6 is: 0.19797232911311669 pixels.
# Average reprojection error for just-triangulated points on image 7 is: 0.21212890902220996 pixels.
# Average reprojection error on image 26 is 0.5507789867819914 pixels
# Average reprojection error on image 27 is 0.3155005560072424 pixels
# Average reprojection error on image 28 is 0.2537323410198642 pixels
# Average reprojection error on image 25 is 0.612525512374386 pixels
# Average reprojection error on image 29 is 0.21523861320795254 pixels
# Average reprojection error on image 24 is 0.4258457853382518 pixels
# Average reprojection error on image 30 is 0.1730399043571008 pixels
# Average reprojection error on image 23 is 0.3824052398234 pixels
# Average reprojection error on image 31 is 0.14004816893635413 pixels
# Average reprojection error on image 22 is 0.3519135418264932 pixels
# Average reprojection error on image 32 is 0.12774885934001953 pixels
# Average reprojection error on image 21 is 0.3363749093869195 pixels
# Average reprojection error on image 33 is 0.1054127578973145 pixels
# Average reprojection error on image 20 is 0.3371844824871867 pixels
# Average reprojection error on image 34 is 0.12111612695364865 pixels
# Average reprojection error on image 19 is 0.3328769990181296 pixels
# Average reprojection error on image 35 is 0.10797832972117398 pixels
# Average reprojection error on image 18 is 0.3214543646963158 pixels
# Average reprojection error on image 0 is 0.1068498808797016 pixels
# Average reprojection error on image 17 is 0.34384599296490215 pixels
# Average reprojection error on image 1 is 0.11269292569771173 pixels
# Average reprojection error on image 16 is 0.31658649000044126 pixels
# Average reprojection error on image 2 is 0.09761351165132967 pixels
# Average reprojection error on image 15 is 0.4369552969781526 pixels
# Average reprojection error on image 3 is 0.35862662530825146 pixels
# Average reprojection error on image 14 is 0.4804092134684096 pixels
# Average reprojection error on image 4 is 0.3195426552414508 pixels
# Average reprojection error on image 13 is 0.44466344088566745 pixels
# Average reprojection error on image 5 is 0.43714102545217337 pixels
# Average reprojection error on image 12 is 0.5438980459567906 pixels
# Average reprojection error on image 6 is 0.5764984433792288 pixels
# Average reprojection error on image 11 is 0.8418964701315451 pixels
# Average reprojection error on image 7 is 0.6907576780657961 pixels
# Average reprojection error across all 33 resected images is 0.34300464167379685 pixels
# Unresected image: 10, resected: 11
# rvec: [[ 240.12487643]
#  [-205.838558  ]
#  [ 178.70895992]]
#
# tvec: [[-1.21177444]
#  [ 2.35196877]
#  [-2.19702004]]
# Average error of reprojecting points used to resect image 10 back onto it is: 1.5702981463496462
# Fraction of Pnp inliers: 0.9 num pts used in Pnp: 120
# Triangulating: 144 points.
# Average reprojection error for just-triangulated points on image 10 is: 0.31761113631685745 pixels.
# Average reprojection error for just-triangulated points on image 11 is: 0.34596278975338524 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         9.0320e+03                                    1.60e+05
#        1              2         6.9640e+03      2.07e+03       9.44e-01       4.58e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 9.0320e+03, final cost 6.9640e+03, first-order optimality 4.58e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         6.9640e+03                                    4.58e+05
#        1              2         5.5058e+03      1.46e+03       1.70e-01       8.50e+02
#        2              3         5.5049e+03      8.30e-01       4.70e-02       1.84e+03
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 6.9640e+03, final cost 5.5049e+03, first-order optimality 1.84e+03.
# Average reprojection error on image 26 is 0.5486303395462448 pixels
# Average reprojection error on image 27 is 0.3165249258427515 pixels
# Average reprojection error on image 28 is 0.2553689460593986 pixels
# Average reprojection error on image 25 is 0.6125693799563723 pixels
# Average reprojection error on image 29 is 0.21733750196189933 pixels
# Average reprojection error on image 24 is 0.429243534565534 pixels
# Average reprojection error on image 30 is 0.17406674227492416 pixels
# Average reprojection error on image 23 is 0.38557631007433635 pixels
# Average reprojection error on image 31 is 0.13970521603691222 pixels
# Average reprojection error on image 22 is 0.35419617664992314 pixels
# Average reprojection error on image 32 is 0.12663461233957934 pixels
# Average reprojection error on image 21 is 0.33838070859607355 pixels
# Average reprojection error on image 33 is 0.10342088501395454 pixels
# Average reprojection error on image 20 is 0.3389639283114361 pixels
# Average reprojection error on image 34 is 0.12131702118138032 pixels
# Average reprojection error on image 19 is 0.3364483146644653 pixels
# Average reprojection error on image 35 is 0.11083713449287953 pixels
# Average reprojection error on image 18 is 0.3313348815338656 pixels
# Average reprojection error on image 0 is 0.11378114331698584 pixels
# Average reprojection error on image 17 is 0.3571916202384907 pixels
# Average reprojection error on image 1 is 0.12218709141716802 pixels
# Average reprojection error on image 16 is 0.3467678035885585 pixels
# Average reprojection error on image 2 is 0.12136845065901943 pixels
# Average reprojection error on image 15 is 0.346485632321912 pixels
# Average reprojection error on image 3 is 0.11889406027595067 pixels
# Average reprojection error on image 14 is 0.2625262107069374 pixels
# Average reprojection error on image 4 is 0.12311687644054123 pixels
# Average reprojection error on image 13 is 0.22429481156529807 pixels
# Average reprojection error on image 5 is 0.11759371643062443 pixels
# Average reprojection error on image 12 is 0.2050072007476359 pixels
# Average reprojection error on image 6 is 0.10178458042349886 pixels
# Average reprojection error on image 11 is 0.16943127213521328 pixels
# Average reprojection error on image 7 is 0.11349079432918696 pixels
# Average reprojection error on image 10 is 0.19714720216098197 pixels
# Average reprojection error across all 34 resected images is 0.2435772066429392 pixels
# Unresected image: 8, resected: 7
# rvec: [[ 4.70470124]
#  [-2.35722397]
#  [-1.4072431 ]]
#
# tvec: [[ 0.45839662]
#  [-2.69644522]
#  [ 7.08447421]]
# Average error of reprojecting points used to resect image 8 back onto it is: 0.36909368709384216
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 127
# Triangulating: 214 points.
# Average reprojection error for just-triangulated points on image 7 is: 2.6641157363065155 pixels.
# Average reprojection error for just-triangulated points on image 8 is: 0.49685491808659743 pixels.
# Average reprojection error on image 26 is 0.5486303395462448 pixels
# Average reprojection error on image 27 is 0.3165249258427515 pixels
# Average reprojection error on image 28 is 0.2553689460593986 pixels
# Average reprojection error on image 25 is 0.6125693799563723 pixels
# Average reprojection error on image 29 is 0.21733750196189933 pixels
# Average reprojection error on image 24 is 0.429243534565534 pixels
# Average reprojection error on image 30 is 0.17406674227492416 pixels
# Average reprojection error on image 23 is 0.38557631007433635 pixels
# Average reprojection error on image 31 is 0.13970521603691222 pixels
# Average reprojection error on image 22 is 0.35419617664992314 pixels
# Average reprojection error on image 32 is 0.12663461233957934 pixels
# Average reprojection error on image 21 is 0.33838070859607355 pixels
# Average reprojection error on image 33 is 0.10342088501395454 pixels
# Average reprojection error on image 20 is 0.3389639283114361 pixels
# Average reprojection error on image 34 is 0.12131702118138032 pixels
# Average reprojection error on image 19 is 0.3364483146644653 pixels
# Average reprojection error on image 35 is 0.11083713449287953 pixels
# Average reprojection error on image 18 is 0.3313348815338656 pixels
# Average reprojection error on image 0 is 0.11378114331698584 pixels
# Average reprojection error on image 17 is 0.3571916202384907 pixels
# Average reprojection error on image 1 is 0.12218709141716802 pixels
# Average reprojection error on image 16 is 0.3467678035885585 pixels
# Average reprojection error on image 2 is 0.12136845065901943 pixels
# Average reprojection error on image 15 is 0.346485632321912 pixels
# Average reprojection error on image 3 is 0.11889406027595067 pixels
# Average reprojection error on image 14 is 0.2625262107069374 pixels
# Average reprojection error on image 4 is 0.12311687644054123 pixels
# Average reprojection error on image 13 is 0.22429481156529807 pixels
# Average reprojection error on image 5 is 0.11759371643062443 pixels
# Average reprojection error on image 12 is 0.2050072007476359 pixels
# Average reprojection error on image 6 is 0.10178458042349886 pixels
# Average reprojection error on image 11 is 0.16943127213521328 pixels
# Average reprojection error on image 7 is 1.0778613554301566 pixels
# Average reprojection error on image 10 is 0.19714720216098197 pixels
# Average reprojection error on image 8 is 0.44927228953505016 pixels
# Average reprojection error across all 35 resected images is 0.2770076536141701 pixels
# Unresected image: 9, resected: 10
# rvec: [[-0.09106039]
#  [-2.67452384]
#  [-0.7187662 ]]
#
# tvec: [[-0.81211035]
#  [ 2.49027223]
#  [-2.14251985]]
# Average error of reprojecting points used to resect image 9 back onto it is: 0.55380430272828
# Fraction of Pnp inliers: 1.0 num pts used in Pnp: 104
# Triangulating: 152 points.
# Average reprojection error for just-triangulated points on image 9 is: 5.7937425816878525 pixels.
# Average reprojection error for just-triangulated points on image 10 is: 25.849413506959582 pixels.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.5470e+05                                    4.67e+06
#        1              2         1.3669e+04      1.41e+05       7.27e+00       6.03e+05
# `ftol` termination condition is satisfied.
# Function evaluations 2, initial cost 1.5470e+05, final cost 1.3669e+04, first-order optimality 6.03e+05.
#    Iteration     Total nfev        Cost      Cost reduction    Step norm     Optimality
#        0              1         1.3669e+04                                    6.03e+05
#        1              2         5.5920e+03      8.08e+03       4.30e-01       1.77e+04
#        2              3         5.5904e+03      1.58e+00       2.60e-02       1.42e+02
# `ftol` termination condition is satisfied.
# Function evaluations 3, initial cost 1.3669e+04, final cost 5.5904e+03, first-order optimality 1.42e+02.
# Average reprojection error on image 26 is 0.5482917065206905 pixels
# Average reprojection error on image 27 is 0.3165756193153666 pixels
# Average reprojection error on image 28 is 0.25552216862660726 pixels
# Average reprojection error on image 25 is 0.612689134845339 pixels
# Average reprojection error on image 29 is 0.21760812832510248 pixels
# Average reprojection error on image 24 is 0.42975735474852805 pixels
# Average reprojection error on image 30 is 0.17398311799797425 pixels
# Average reprojection error on image 23 is 0.3859465910124738 pixels
# Average reprojection error on image 31 is 0.1395368082973153 pixels
# Average reprojection error on image 22 is 0.3544154492258784 pixels
# Average reprojection error on image 32 is 0.12672146972717613 pixels
# Average reprojection error on image 21 is 0.33836706680607925 pixels
# Average reprojection error on image 33 is 0.10352369736410033 pixels
# Average reprojection error on image 20 is 0.338922572899623 pixels
# Average reprojection error on image 34 is 0.12129975869191612 pixels
# Average reprojection error on image 19 is 0.33677824177086174 pixels
# Average reprojection error on image 35 is 0.11077485339052151 pixels
# Average reprojection error on image 18 is 0.3321940681116106 pixels
# Average reprojection error on image 0 is 0.11379298731817564 pixels
# Average reprojection error on image 17 is 0.357996839917942 pixels
# Average reprojection error on image 1 is 0.12247570338987473 pixels
# Average reprojection error on image 16 is 0.3488680665190834 pixels
# Average reprojection error on image 2 is 0.12220079811693163 pixels
# Average reprojection error on image 15 is 0.3490573907670609 pixels
# Average reprojection error on image 3 is 0.1198331034523521 pixels
# Average reprojection error on image 14 is 0.26439758702571103 pixels
# Average reprojection error on image 4 is 0.12695936935576357 pixels
# Average reprojection error on image 13 is 0.23210757955481454 pixels
# Average reprojection error on image 5 is 0.12135626940137487 pixels
# Average reprojection error on image 12 is 0.2159049067381165 pixels
# Average reprojection error on image 6 is 0.10925311850541211 pixels
# Average reprojection error on image 11 is 0.18377537583239456 pixels
# Average reprojection error on image 7 is 0.09745419303730518 pixels
# Average reprojection error on image 10 is 0.17386644229169151 pixels
# Average reprojection error on image 8 is 0.11322396871445926 pixels
# Average reprojection error on image 9 is 0.18375904464963924 pixels
# Average reprojection error across all 36 resected images is 0.2388664042295908 pixels

# %%
import plotly.graph_objects as go

def plot_model(points3d_with_views):
    # Extract the 3D points from points3d_with_views
    pts_cloud = np.array([pt3.point3d[0] for pt3 in points3d_with_views if np.abs(pt3.point3d[0]).sum() < 200])

    # Assuming points_3D is your array of 3D points
    x = pts_cloud[:, 0]
    y = pts_cloud[:, 1]
    z = pts_cloud[:, 2]

    fig = go.Figure(data=[go.Scatter3d(
        x=x,
        y=y,
        z=z,
        mode='markers',
        marker=dict(
            size=2,
            color=z,                # set color to an array/list of desired values
            colorscale='Viridis',   # choose a colorscale
            opacity=0.8
        )
    )])

    # tight layout
    fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
    fig.show()
plot_model(points3d_with_views)
